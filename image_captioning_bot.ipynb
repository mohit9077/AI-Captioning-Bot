# %%
import json
import cv2
import matplotlib.pyplot as plt
import re
import collections
import pandas as pd
import numpy as np

# %%
from keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from keras.models import Model,load_model
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.utils import to_categorical
from keras.layers import Input,Dense,Dropout,Embedding,LSTM
from keras.layers.merge import add
from time import time
import pickle
import string
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input,Dense,LSTM,Dropout,Embedding
# Out:
# Using TensorFlow backend.

# %%
#### reading the textfiles(captions)

# %%
def readText(path):
    with open(path) as f:
        captions=f.read()
        
    return captions

# %%
captions=readText("./flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr8k.token.txt")
captions=captions.split("\n")[:-1] ### discarding the last line
###### last line is empty

# %%
len(captions) ############ here we can easily read the caption
# Out:
# 40460

# %%
print(captions[0])
# Out:
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .

# %%
first,second=captions[0].split('\t')
print(first)
print(second)
print(first.split('.')[0])
# Out:
# 1000268201_693b08cb0e.jpg#0
# A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e

# %%
#### lets create a dictionary to map each image with the list of captions it has
dictionary={}  ## dictionary for mapping

for cap in captions:
    first,second=cap.split('\t')
    img_name=first.split('.')[0]
    
    
    ### if the image id is already present or not
    if dictionary.get(img_name) is None:
        dictionary[img_name]=[]  ## here with particular img if no caption is added the we initialise with empty list
        
        
    dictionary[img_name].append(second) ### if the image is already present than add it to a list

# %%
dictionary["1000268201_693b08cb0e"]
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
img_path="flickr8k/Flickr_Data/Flickr_Data/Images/"

# %%
img=cv2.imread(img_path+"1000268201_693b08cb0e.jpg")
img_=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_)
plt.axis("OFF")
plt.show()

# %% [markdown]
# ### cleaning the Text

# %%
### here we should not remove stopwords does not do stemming to produce correct caption

### cleaning the text
def clean_text(sentence):
    sentence=sentence.lower() ### so that "the The" remain same
    sentence=re.sub("[^a-z]+"," ",sentence)  ### subsitute space if any of charcater is present other alphabets
    sentence=sentence.split()  ## splitting the sentence into words
    print(sentence)
    sentence=[s for s in sentence if len(s)>1]
    sentence=" ".join(sentence)  ## joining it again
    return sentence

# %% [markdown]
# ### cleaning all the captions

# %%
for key,caption_list in dictionary.items():
    
    for i in range(len(caption_list)):
        caption_list[i]=clean_text(caption_list[i])
# Out:
# ['child', 'in', 'pink', 'dress', 'is', 'climbing', 'up', 'set', 'of', 'stairs', 'in', 'an', 'entry', 'way']
# ['girl', 'going', 'into', 'wooden', 'building']
# ['little', 'girl', 'climbing', 'into', 'wooden', 'playhouse']
# ['little', 'girl', 'climbing', 'the', 'stairs', 'to', 'her', 'playhouse']
# ['little', 'girl', 'in', 'pink', 'dress', 'going', 'into', 'wooden', 'cabin']
# ['black', 'dog', 'and', 'spotted', 'dog', 'are', 'fighting']
# ['black', 'dog', 'and', 'tri', 'colored', 'dog', 'playing', 'with', 'each', 'other', 'on', 'the', 'road']
# ['black', 'dog', 'and', 'white', 'dog', 'with', 'brown', 'spots', 'are', 'staring', 'at', 'each', 'other', 'in', 'the', 'street']
# ['two', 'dogs', 'of', 'different', 'breeds', 'looking', 'at', 'each', 'other', 'on', 'the', 'road']
# ['two', 'dogs', 'on', 'pavement', 'moving', 'toward', 'each', 'other']
# ['little', 'girl', 'covered', 'in', 'paint', 'sits', 'in', 'front', 'of', 'painted', 'rainbow', 'with', 'her', 'hands', 'in', 'bowl']
# ['little', 'girl', 'is', 'sitting', 'in', 'front', 'of', 'large', 'painted', 'rainbow']
# ['small', 'girl', 'in', 'the', 'grass', 'plays', 'with', 'fingerpaints', 'in', 'front', 'of', 'white', 'canvas', 'with', 'rainbow', 'on', 'it']
# ['there', 'is', 'girl', 'with', 'pigtails', 'sitting', 'in', 'front', 'of', 'rainbow', 'painting']
# ['young', 'girl', 'with', 'pigtails', 'painting', 'outside', 'in', 'the', 'grass']
# ['man', 'lays', 'on', 'bench', 'while', 'his', 'dog', 'sits', 'by', 'him']
# ['man', 'lays', 'on', 'the', 'bench', 'to', 'which', 'white', 'dog', 'is', 'also', 'tied']
# ['man', 'sleeping', 'on', 'bench', 'outside', 'with', 'white', 'and', 'black', 'dog', 'sitting', 'next', 'to', 'him']
# ['shirtless', 'man', 'lies', 'on', 'park', 'bench', 'with', 'his', 'dog']
# ['man', 'laying', 'on', 'bench', 'holding', 'leash', 'of', 'dog', 'sitting', 'on', 'ground']
# ['man', 'in', 'an', 'orange', 'hat', 'starring', 'at', 'something']
# ['man', 'wears', 'an', 'orange', 'hat', 'and', 'glasses']
# ['man', 'with', 'gauges', 'and', 'glasses', 'is', 'wearing', 'blitz', 'hat']
# ['man', 'with', 'glasses', 'is', 'wearing', 'beer', 'can', 'crocheted', 'hat']
# ['the', 'man', 'with', 'pierced', 'ears', 'is', 'wearing', 'glasses', 'and', 'an', 'orange', 'hat']
# ['child', 'playing', 'on', 'rope', 'net']
# ['little', 'girl', 'climbing', 'on', 'red', 'roping']
# ['little', 'girl', 'in', 'pink', 'climbs', 'rope', 'bridge', 'at', 'the', 'park']
# ['small', 'child', 'grips', 'onto', 'the', 'red', 'ropes', 'at', 'the', 'playground']
# ['the', 'small', 'child', 'climbs', 'on', 'red', 'ropes', 'on', 'playground']
# ['black', 'and', 'white', 'dog', 'is', 'running', 'in', 'grassy', 'garden', 'surrounded', 'by', 'white', 'fence']
# ['black', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'grass']
# ['boston', 'terrier', 'is', 'running', 'in', 'the', 'grass']
# ['boston', 'terrier', 'is', 'running', 'on', 'lush', 'green', 'grass', 'in', 'front', 'of', 'white', 'fence']
# ['dog', 'runs', 'on', 'the', 'green', 'grass', 'near', 'wooden', 'fence']
# ['dog', 'shakes', 'its', 'head', 'near', 'the', 'shore', 'red', 'ball', 'next', 'to', 'it']
# ['white', 'dog', 'shakes', 'on', 'the', 'edge', 'of', 'beach', 'with', 'an', 'orange', 'ball']
# ['dog', 'with', 'orange', 'ball', 'at', 'feet', 'stands', 'on', 'shore', 'shaking', 'off', 'water']
# ['white', 'dog', 'playing', 'with', 'red', 'ball', 'on', 'the', 'shore', 'near', 'the', 'water']
# ['white', 'dog', 'with', 'brown', 'ears', 'standing', 'near', 'water', 'with', 'head', 'turned', 'to', 'one', 'side']
# ['boy', 'smiles', 'in', 'front', 'of', 'stony', 'wall', 'in', 'city']
# ['little', 'boy', 'is', 'standing', 'on', 'the', 'street', 'while', 'man', 'in', 'overalls', 'is', 'working', 'on', 'stone', 'wall']
# ['young', 'boy', 'runs', 'aross', 'the', 'street']
# ['young', 'child', 'is', 'walking', 'on', 'stone', 'paved', 'street', 'with', 'metal', 'pole', 'and', 'man', 'behind', 'him']
# ['smiling', 'boy', 'in', 'white', 'shirt', 'and', 'blue', 'jeans', 'in', 'front', 'of', 'rock', 'wall', 'with', 'man', 'in', 'overalls', 'behind', 'him']
# ['black', 'dog', 'leaps', 'over', 'log']
# ['grey', 'dog', 'is', 'leaping', 'over', 'fallen', 'tree']
# ['large', 'black', 'dog', 'leaps', 'fallen', 'log']
# ['mottled', 'black', 'and', 'grey', 'dog', 'in', 'blue', 'collar', 'jumping', 'over', 'fallen', 'tree']
# ['the', 'black', 'dog', 'jumped', 'the', 'tree', 'stump']
# ['brown', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'snow']
# ['dog', 'is', 'running', 'in', 'the', 'snow']
# ['dog', 'running', 'through', 'snow']
# ['white', 'and', 'brown', 'dog', 'is', 'running', 'through', 'snow', 'covered', 'field']
# ['the', 'white', 'and', 'brown', 'dog', 'is', 'running', 'over', 'the', 'surface', 'of', 'the', 'snow']
# ['man', 'in', 'hat', 'is', 'displaying', 'pictures', 'next', 'to', 'skier', 'in', 'blue', 'hat']
# ['man', 'skis', 'past', 'another', 'man', 'displaying', 'paintings', 'in', 'the', 'snow']
# ['person', 'wearing', 'skis', 'looking', 'at', 'framed', 'pictures', 'set', 'up', 'in', 'the', 'snow']
# ['skier', 'looks', 'at', 'framed', 'pictures', 'in', 'the', 'snow', 'next', 'to', 'trees']
# ['man', 'on', 'skis', 'looking', 'at', 'artwork', 'for', 'sale', 'in', 'the', 'snow']
# ['collage', 'of', 'one', 'person', 'climbing', 'cliff']
# ['group', 'of', 'people', 'are', 'rock', 'climbing', 'on', 'rock', 'climbing', 'wall']
# ['group', 'of', 'people', 'climbing', 'rock', 'while', 'one', 'man', 'belays']
# ['seven', 'climbers', 'are', 'ascending', 'rock', 'face', 'whilst', 'another', 'man', 'stands', 'holding', 'the', 'rope']
# ['several', 'climbers', 'in', 'row', 'are', 'climbing', 'the', 'rock', 'while', 'the', 'man', 'in', 'red', 'watches', 'and', 'holds', 'the', 'line']
# ['brown', 'dog', 'chases', 'the', 'water', 'from', 'sprinkler', 'on', 'lawn']
# ['brown', 'dog', 'plays', 'with', 'the', 'hose']
# ['brown', 'dog', 'running', 'on', 'lawn', 'near', 'garden', 'hose']
# ['dog', 'is', 'playing', 'with', 'hose']
# ['large', 'brown', 'dog', 'running', 'away', 'from', 'the', 'sprinkler', 'in', 'the', 'grass']
# ['dog', 'prepares', 'to', 'catch', 'thrown', 'object', 'in', 'field', 'with', 'nearby', 'cars']
# ['white', 'dog', 'is', 'about', 'to', 'catch', 'yellow', 'ball', 'in', 'its', 'mouth']
# ['white', 'dog', 'is', 'about', 'to', 'catch', 'yellow', 'dog', 'toy']
# ['white', 'dog', 'is', 'ready', 'to', 'catch', 'yellow', 'ball', 'flying', 'through', 'the', 'air']
# ['white', 'dog', 'running', 'after', 'yellow', 'ball']
# ['black', 'and', 'white', 'dog', 'jumping', 'in', 'the', 'air', 'to', 'get', 'toy']
# ['black', 'and', 'white', 'dog', 'jumps', 'up', 'towards', 'yellow', 'toy']
# ['dog', 'leaps', 'to', 'catch', 'ball', 'in', 'field']
# ['white', 'dog', 'is', 'trying', 'to', 'catch', 'ball', 'in', 'midair', 'over', 'grassy', 'field']
# ['the', 'white', 'dog', 'is', 'playing', 'in', 'green', 'field', 'with', 'yellow', 'toy']
# ['child', 'and', 'woman', 'are', 'at', 'waters', 'edge', 'in', 'big', 'city']
# ['large', 'lake', 'with', 'lone', 'duck', 'swimming', 'in', 'it', 'with', 'several', 'people', 'around', 'the', 'edge', 'of', 'it']
# ['little', 'boy', 'at', 'lake', 'watching', 'duck']
# ['young', 'boy', 'waves', 'his', 'hand', 'at', 'the', 'duck', 'in', 'the', 'water', 'surrounded', 'by', 'green', 'park']
# ['two', 'people', 'are', 'at', 'the', 'edge', 'of', 'lake', 'facing', 'the', 'water', 'and', 'the', 'city', 'skyline']
# ['couple', 'and', 'an', 'infant', 'being', 'held', 'by', 'the', 'male', 'sitting', 'next', 'to', 'pond', 'with', 'near', 'by', 'stroller']
# ['couple', 'sit', 'on', 'the', 'grass', 'with', 'baby', 'and', 'stroller']
# ['couple', 'with', 'their', 'newborn', 'baby', 'sitting', 'under', 'tree', 'facing', 'lake']
# ['man', 'and', 'woman', 'care', 'for', 'an', 'infant', 'along', 'the', 'side', 'of', 'body', 'of', 'water']
# ['couple', 'with', 'baby', 'sit', 'outdoors', 'next', 'to', 'their', 'stroller']
# ['black', 'dog', 'running', 'in', 'the', 'surf']
# ['black', 'lab', 'with', 'tags', 'frolicks', 'in', 'the', 'water']
# ['dog', 'splashes', 'in', 'the', 'water']
# ['the', 'black', 'dog', 'runs', 'through', 'the', 'water']
# ['this', 'is', 'black', 'dog', 'splashing', 'in', 'the', 'water']
# ['man', 'drilling', 'hole', 'in', 'the', 'ice']
# ['man', 'is', 'drilling', 'through', 'the', 'frozen', 'ice', 'of', 'pond']
# ['person', 'in', 'the', 'snow', 'drilling', 'hole', 'in', 'the', 'ice']
# ['person', 'standing', 'on', 'frozen', 'lake']
# ['two', 'men', 'are', 'ice', 'fishing']
# ['two', 'different', 'breeds', 'of', 'brown', 'and', 'white', 'dogs', 'play', 'on', 'the', 'beach']
# ['two', 'dogs', 'are', 'making', 'turn', 'on', 'soft', 'sand', 'beach']
# ['two', 'dogs', 'playing', 'in', 'the', 'sand', 'at', 'the', 'beach']
# ['two', 'dogs', 'playing', 'together', 'on', 'beach']
# ['two', 'large', 'tan', 'dogs', 'play', 'along', 'sandy', 'beach']
# ['man', 'uses', 'ice', 'picks', 'and', 'crampons', 'to', 'scale', 'ice']
# ['an', 'ice', 'climber', 'in', 'blue', 'jacket', 'and', 'black', 'pants', 'is', 'scaling', 'frozen', 'ice', 'wall']
# ['an', 'ice', 'climber', 'scaling', 'frozen', 'waterfall']
# ['person', 'in', 'blue', 'and', 'red', 'ice', 'climbing', 'with', 'two', 'picks']
# ['climber', 'climbing', 'an', 'ice', 'wall']
# ['black', 'dog', 'carries', 'green', 'toy', 'in', 'his', 'mouth', 'as', 'he', 'walks', 'through', 'the', 'grass']
# ['black', 'dog', 'carrying', 'something', 'through', 'the', 'grass']
# ['black', 'dog', 'has', 'blue', 'toy', 'in', 'its', 'mouth']
# ['dog', 'in', 'grass', 'with', 'blue', 'item', 'in', 'his', 'mouth']
# ['wet', 'black', 'dog', 'is', 'carrying', 'green', 'toy', 'through', 'the', 'grass']
# ['man', 'and', 'baby', 'are', 'in', 'yellow', 'kayak', 'on', 'water']
# ['man', 'and', 'little', 'boy', 'in', 'blue', 'life', 'jackets', 'are', 'rowing', 'yellow', 'canoe']
# ['man', 'and', 'child', 'kayak', 'through', 'gentle', 'waters']
# ['man', 'and', 'young', 'boy', 'ride', 'in', 'yellow', 'kayak']
# ['man', 'and', 'child', 'in', 'yellow', 'kayak']
# ['black', 'dog', 'and', 'brown', 'dog', 'are', 'jumping', 'up', 'to', 'catch', 'red', 'toy']
# ['black', 'dog', 'and', 'brown', 'dog', 'play', 'with', 'red', 'toy', 'on', 'courtyard']
# ['brown', 'and', 'black', 'lab', 'are', 'outside', 'and', 'the', 'black', 'lab', 'is', 'catching', 'toy', 'in', 'its', 'mouth']
# ['black', 'dog', 'snaps', 'at', 'red', 'and', 'black', 'object', 'as', 'brown', 'dog', 'lunges']
# ['the', 'chocolate', 'lab', 'jumps', 'too', 'late', 'to', 'get', 'the', 'toy', 'as', 'the', 'black', 'lab', 'captures', 'it', 'in', 'the', 'driveway']
# ['boy', 'with', 'stick', 'kneeling', 'in', 'front', 'of', 'goalie', 'net']
# ['child', 'in', 'red', 'jacket', 'playing', 'street', 'hockey', 'guarding', 'goal']
# ['young', 'kid', 'playing', 'the', 'goalie', 'in', 'hockey', 'rink']
# ['young', 'male', 'kneeling', 'in', 'front', 'of', 'hockey', 'goal', 'with', 'hockey', 'stick', 'in', 'his', 'right', 'hand']
# ['hockey', 'goalie', 'boy', 'in', 'red', 'jacket', 'crouches', 'by', 'goal', 'with', 'stick']
# ['man', 'in', 'black', 'is', 'sitting', 'next', 'to', 'modern', 'art', 'structure', 'in', 'front', 'of', 'glass', 'building']
# ['man', 'sits', 'and', 'reads', 'newspaper', 'by', 'sculpture', 'outside', 'of', 'an', 'office', 'building']
# ['man', 'sits', 'near', 'large', 'statue']
# ['man', 'sitting', 'in', 'front', 'of', 'metal', 'sculpture', 'in', 'front', 'of', 'building']
# ['the', 'man', 'with', 'the', 'backpack', 'is', 'sitting', 'in', 'buildings', 'courtyard', 'in', 'front', 'of', 'an', 'art', 'sculpture', 'reading']
# ['tent', 'is', 'being', 'set', 'up', 'on', 'the', 'ice']
# ['two', 'men', 'are', 'about', 'to', 'enter', 'an', 'ice', 'fishing', 'tent', 'on', 'snow', 'covered', 'lake']
# ['two', 'men', 'setting', 'up', 'blue', 'ice', 'fishing', 'hut', 'on', 'an', 'iced', 'over', 'lake']
# ['two', 'men', 'standing', 'on', 'an', 'ice', 'looking', 'into', 'something', 'covered', 'with', 'blue', 'tarp']
# ['two', 'people', 'standing', 'outside', 'blue', 'tent', 'structure', 'on', 'snowy', 'surface']
# ['woman', 'crouches', 'near', 'three', 'dogs', 'in', 'field']
# ['three', 'dogs', 'are', 'playing', 'on', 'grassy', 'hill', 'with', 'blue', 'sky']
# ['three', 'dogs', 'are', 'standing', 'in', 'the', 'grass', 'and', 'person', 'is', 'sitting', 'next', 'to', 'them']
# ['three', 'dogs', 'on', 'grassy', 'hill']
# ['three', 'dogs', 'stand', 'in', 'grassy', 'field', 'while', 'person', 'kneels', 'nearby']
# ['man', 'is', 'standing', 'in', 'front', 'of', 'skyscraper']
# ['man', 'stands', 'in', 'front', 'of', 'skyscraper']
# ['man', 'stands', 'in', 'front', 'of', 'very', 'tall', 'building']
# ['behind', 'the', 'man', 'in', 'red', 'shirt', 'stands', 'large', 'skyscraper']
# ['there', 'is', 'skyscraper', 'in', 'the', 'distance', 'with', 'man', 'walking', 'in', 'front', 'of', 'the', 'camera']
# ['boy', 'bites', 'hard', 'into', 'treat', 'while', 'he', 'sits', 'outside']
# ['child', 'biting', 'into', 'baked', 'good']
# ['small', 'boy', 'putting', 'something', 'in', 'his', 'mouth', 'with', 'both', 'hands']
# ['the', 'boy', 'eats', 'his', 'food', 'outside', 'at', 'the', 'table']
# ['the', 'boy', 'is', 'eating', 'pizza', 'over', 'tin', 'dish']
# ['people', 'sit', 'on', 'the', 'mountainside', 'and', 'check', 'out', 'the', 'view']
# ['three', 'people', 'are', 'on', 'hilltop', 'overlooking', 'green', 'valley']
# ['three', 'people', 'hang', 'out', 'on', 'top', 'of', 'big', 'hill']
# ['three', 'people', 'overlook', 'green', 'valley']
# ['three', 'people', 'rest', 'on', 'ledge', 'above', 'the', 'moutains']
# ['boy', 'in', 'green', 'shirt', 'is', 'looking', 'down', 'at', 'many', 'inflatable', 'boats']
# ['boy', 'in', 'green', 'shirt', 'watches', 'kayakers']
# ['boy', 'looks', 'over', 'railing', 'at', 'the', 'many', 'boats', 'and', 'rafts', 'below', 'in', 'the', 'water']
# ['young', 'boy', 'overlooking', 'crowd', 'of', 'inflatable', 'boats']
# ['young', 'boy', 'wearing', 'jersey', 'looks', 'down', 'over', 'ledge', 'at', 'many', 'boats', 'in', 'the', 'water']
# ['man', 'and', 'woman', 'pose', 'for', 'the', 'camera', 'while', 'another', 'man', 'looks', 'on']
# ['man', 'is', 'holding', 'the', 'hand', 'of', 'woman', 'up', 'to', 'his', 'mouth', 'in', 'front', 'of', 'some', 'buildings', 'while', 'another', 'man', 'looks', 'on']
# ['multiracial', 'couple', 'posing', 'for', 'picture']
# ['asian', 'man', 'and', 'blond', 'woman', 'holding', 'hands', 'outdoors', 'man', 'in', 'background', 'watches']
# ['guy', 'in', 'blue', 'shirt', 'biting', 'hand', 'of', 'girl', 'in', 'black', 'striped', 'jacket', 'while', 'another', 'guy', 'watches']
# ['person', 'eats', 'takeout', 'while', 'watching', 'small', 'television']
# ['person', 'sits', 'on', 'the', 'floor', 'and', 'eats', 'in', 'front', 'of', 'television']
# ['television', 'with', 'picture', 'of', 'girl', 'on', 'it']
# ['young', 'man', 'sits', 'on', 'the', 'floor', 'by', 'the', 'television', 'with', 'fast', 'food', 'meal', 'in', 'front', 'of', 'him']
# ['someone', 'is', 'laying', 'in', 'front', 'of', 'the', 'tv', 'eating', 'food']
# ['couple', 'of', 'several', 'people', 'sitting', 'on', 'ledge', 'overlooking', 'the', 'beach']
# ['group', 'of', 'people', 'sit', 'on', 'wall', 'at', 'the', 'beach']
# ['group', 'of', 'teens', 'sit', 'on', 'wall', 'by', 'beach']
# ['crowd', 'of', 'people', 'at', 'the', 'beach']
# ['several', 'young', 'people', 'sitting', 'on', 'rail', 'above', 'crowded', 'beach']
# ['boy', 'takes', 'jump', 'on', 'his', 'skateboard', 'while', 'another', 'boy', 'with', 'skateboard', 'watches']
# ['child', 'is', 'performing', 'skateboard', 'trick', 'while', 'another', 'child', 'with', 'skateboard', 'leans', 'on', 'wall']
# ['little', 'boy', 'skateboarder', 'is', 'doing', 'trick', 'on', 'his', 'board', 'while', 'another', 'young', 'skateboarder', 'watches']
# ['young', 'boy', 'skateboarder', 'jumping', 'on', 'platform', 'on', 'skateboard']
# ['two', 'skateboarders']
# ['girl', 'paddling', 'down', 'large', 'river', 'as', 'seen', 'from', 'behind', 'her']
# ['woman', 'kayaking', 'down', 'river']
# ['woman', 'paddles', 'boat', 'down', 'river']
# ['woman', 'with', 'paddle']
# ['woman', 'with', 'paddle', 'sits', 'in', 'boat', 'on', 'the', 'water']
# ['girl', 'in', 'pigtails', 'splashes', 'in', 'the', 'shallow', 'water']
# ['girls', 'plays', 'in', 'the', 'surf']
# ['girl', 'with', 'pigtails', 'is', 'playing', 'in', 'the', 'ocean', 'by', 'the', 'beach']
# ['girl', 'with', 'pigtails', 'plays', 'in', 'the', 'water']
# ['young', 'girl', 'in', 'pigtails', 'plays', 'in', 'the', 'water']
# ['group', 'of', 'four', 'children', 'wearing', 'pajamas', 'have', 'pillow', 'fight']
# ['group', 'of', 'kids', 'have', 'pillow', 'fight']
# ['group', 'of', 'young', 'children', 'playing', 'pillow', 'fight', 'on', 'bed']
# ['children', 'having', 'pillow', 'fight']
# ['four', 'children', 'are', 'having', 'pillow', 'fight']
# ['two', 'constructions', 'workers', 'sit', 'on', 'beam', 'taking', 'break']
# ['two', 'construction', 'workers', 'are', 'sitting', 'up', 'on', 'the', 'side', 'of', 'building']
# ['two', 'construction', 'workers', 'sitting', 'on', 'an', 'beam']
# ['two', 'construction', 'workers', 'take', 'seat', 'on', 'steel', 'beam']
# ['two', 'men', 'take', 'break', 'from', 'construction']
# ['the', 'children', 'are', 'playing', 'in', 'the', 'water']
# ['two', 'boys', 'one', 'with', 'yellow', 'and', 'orange', 'ball', 'play', 'in', 'some', 'water', 'in', 'front', 'of', 'field']
# ['two', 'boys', 'play', 'in', 'puddle']
# ['two', 'children', 'play', 'with', 'balloon', 'in', 'mud', 'on', 'sunny', 'day']
# ['two', 'kids', 'are', 'running', 'and', 'playing', 'in', 'some', 'water']
# ['blond', 'woman', 'in', 'blue', 'shirt', 'appears', 'to', 'wait', 'for', 'ride']
# ['blond', 'woman', 'is', 'on', 'the', 'street', 'hailing', 'taxi']
# ['woman', 'is', 'signaling', 'is', 'to', 'traffic', 'as', 'seen', 'from', 'behind']
# ['woman', 'with', 'blonde', 'hair', 'wearing', 'blue', 'tube', 'top', 'is', 'waving', 'on', 'the', 'side', 'of', 'the', 'street']
# ['the', 'woman', 'in', 'the', 'blue', 'dress', 'is', 'holding', 'out', 'her', 'arm', 'at', 'oncoming', 'traffic']
# ['little', 'girl', 'looking', 'at', 'brochure', 'on', 'train', 'rides']
# ['young', 'blond', 'girl', 'with', 'magizine', 'in', 'her', 'hands']
# ['young', 'girl', 'on', 'train', 'reads', 'book', 'about', 'train', 'rides']
# ['young', 'girl', 'sits', 'on', 'seat', 'and', 'looks', 'at', 'train', 'pamphlet']
# ['child', 'sitting', 'down', 'looking', 'at', 'train', 'ride', 'brochure']
# ['brown', 'dog', 'is', 'running', 'after', 'black', 'dog', 'on', 'rocky', 'shore']
# ['brown', 'dog', 'is', 'running', 'after', 'the', 'black', 'dog']
# ['two', 'dogs', 'playing', 'on', 'beach']
# ['two', 'dogs', 'run', 'across', 'stones', 'near', 'body', 'of', 'water']
# ['two', 'dogs', 'run', 'towards', 'each', 'other', 'on', 'rocky', 'area', 'with', 'water', 'in', 'the', 'background']
# ['boy', 'descends', 'off', 'the', 'end', 'of', 'high', 'diving', 'board']
# ['child', 'jumps', 'off', 'high', 'diving', 'board', 'into', 'the', 'pool']
# ['kid', 'jumps', 'off', 'the', 'diving', 'board', 'and', 'into', 'the', 'swimming', 'pool', 'below']
# ['little', 'kid', 'is', 'jumping', 'off', 'high', 'dive', 'at', 'the', 'pool']
# ['the', 'boy', 'is', 'jumping', 'off', 'high', 'diving', 'board', 'into', 'the', 'pool']
# ['guy', 'stands', 'by', 'window', 'taking', 'his', 'overshirt', 'off']
# ['man', 'in', 'tank', 'top', 'stands', 'next', 'to', 'chrome', 'door']
# ['man', 'puts', 'his', 'shirt', 'on', 'near', 'an', 'elevator']
# ['man', 'stands', 'by', 'an', 'elevator', 'with', 'his', 'head', 'down']
# ['the', 'man', 'is', 'putting', 'on', 'his', 'shirt', 'near', 'an', 'elevator']
# ['light', 'colored', 'dog', 'runs', 'on', 'the', 'beach']
# ['small', 'yellow', 'dog', 'runs', 'on', 'beach']
# ['tan', 'dog', 'runs', 'on', 'sandy', 'beach']
# ['white', 'dog', 'is', 'running', 'down', 'rocky', 'beach']
# ['light', 'brown', 'dog', 'running', 'along', 'the', 'beach']
# ['boy', 'in', 'his', 'blue', 'swim', 'shorts', 'at', 'the', 'beach']
# ['boy', 'smiles', 'for', 'the', 'camera', 'at', 'beach']
# ['young', 'boy', 'in', 'swimming', 'trunks', 'is', 'walking', 'with', 'his', 'arms', 'outstretched', 'on', 'the', 'beach']
# ['children', 'playing', 'on', 'the', 'beach']
# ['the', 'boy', 'is', 'playing', 'on', 'the', 'shore', 'of', 'an', 'ocean']
# ['hiker', 'standing', 'high', 'on', 'bluff', 'overlooking', 'the', 'mountains', 'below']
# ['person', 'on', 'ski', 'looks', 'from', 'hill', 'over', 'snow', 'covered', 'landscape']
# ['skier', 'is', 'overlooking', 'snow', 'covered', 'mountain']
# ['skier', 'is', 'overlooking', 'the', 'beautiful', 'white', 'snow', 'covered', 'landscape']
# ['skier', 'pauses', 'on', 'mountaintop']
# ['black', 'and', 'white', 'dog', 'is', 'attempting', 'to', 'catch', 'yellow', 'and', 'purple', 'object', 'in', 'low', 'cut', 'yard']
# ['black', 'and', 'white', 'dog', 'jumps', 'after', 'yellow', 'toy']
# ['black', 'and', 'white', 'dog', 'jumps', 'to', 'get', 'the', 'frisbee']
# ['black', 'dog', 'is', 'jumping', 'up', 'to', 'catch', 'purple', 'and', 'green', 'toy']
# ['dog', 'jumps', 'to', 'catch', 'toy']
# ['man', 'in', 'blue', 'shorts', 'is', 'laying', 'in', 'the', 'street']
# ['man', 'in', 'blue', 'shorts', 'lays', 'down', 'outside', 'in', 'parking', 'lot']
# ['man', 'laying', 'down', 'in', 'middle', 'of', 'street', 'during', 'heavy', 'traffic']
# ['man', 'lies', 'on', 'mat', 'in', 'parking', 'lot', 'between', 'brown', 'suv', 'and', 'yellow', 'pickup', 'with', 'an', 'open', 'door']
# ['shirtless', 'man', 'is', 'laying', 'down', 'in', 'the', 'middle', 'of', 'busy', 'street']
# ['white', 'and', 'black', 'dog', 'and', 'brown', 'dog', 'in', 'sandy', 'terrain']
# ['woolly', 'dog', 'chases', 'doberman', 'on', 'beach']
# ['one', 'dog', 'is', 'chasing', 'another', 'one', 'on', 'the', 'beach']
# ['the', 'two', 'large', 'dogs', 'are', 'running', 'through', 'sand']
# ['two', 'large', 'dogs', 'chasing', 'each', 'other', 'at', 'the', 'beach']
# ['black', 'and', 'white', 'dog', 'catches', 'toy', 'in', 'midair']
# ['dog', 'and', 'tennis', 'ball']
# ['dog', 'is', 'jumping', 'to', 'catch', 'object', 'thrown', 'at', 'it']
# ['dog', 'leaps', 'while', 'chasing', 'tennis', 'ball', 'through', 'grassy', 'field']
# ['multicolor', 'dog', 'jumping', 'to', 'catch', 'tennis', 'ball', 'in', 'grassy', 'field']
# ['crowd', 'watching', 'air', 'balloons', 'at', 'night']
# ['group', 'of', 'hot', 'air', 'balloons', 'lit', 'up', 'at', 'night']
# ['people', 'are', 'watching', 'hot', 'air', 'balloons', 'in', 'the', 'park']
# ['people', 'watching', 'hot', 'air', 'balloons']
# ['seven', 'large', 'balloons', 'are', 'lined', 'up', 'at', 'nighttime', 'near', 'crowd']
# ['child', 'with', 'helmet', 'on', 'his', 'head', 'rides', 'bike']
# ['little', 'boy', 'rides', 'bike', 'down', 'hill', 'on', 'miniature', 'dirt', 'bike']
# ['young', 'boy', 'in', 'helmet', 'rides', 'bike', 'on', 'the', 'road']
# ['the', 'little', 'boy', 'rides', 'his', 'bicycle', 'in', 'race']
# ['the', 'young', 'boy', 'pedals', 'quickly', 'at', 'bmx', 'race']
# ['group', 'of', 'eight', 'people', 'are', 'gathered', 'around', 'table', 'at', 'night']
# ['group', 'of', 'people', 'gathered', 'around', 'in', 'the', 'dark']
# ['group', 'of', 'people', 'sit', 'around', 'table', 'outside', 'on', 'porch', 'at', 'night']
# ['group', 'of', 'people', 'sit', 'outdoors', 'together', 'at', 'night']
# ['group', 'of', 'people', 'sitting', 'at', 'table', 'in', 'darkened', 'room']
# ['man', 'in', 'brown', 'shirt', 'and', 'dark', 'shorts', 'plays', 'on', 'the', 'beach', 'with', 'his', 'two', 'black', 'dogs']
# ['man', 'in', 'shorts', 'with', 'two', 'black', 'dogs', 'holds', 'ball', 'throwing', 'toy', 'at', 'the', 'beach']
# ['man', 'playing', 'with', 'two', 'black', 'dogs', 'on', 'the', 'beach']
# ['man', 'with', 'two', 'dogs', 'on', 'beach']
# ['man', 'at', 'the', 'beach', 'with', 'two', 'dogs']
# ['boy', 'cleans', 'the', 'bubbles', 'off', 'his', 'face']
# ['boy', 'covered', 'in', 'suds', 'has', 'his', 'face', 'wiped', 'clean']
# ['boy', 'is', 'covered', 'in', 'bubbles']
# ['child', 'covered', 'in', 'foam', 'is', 'climbing', 'on', 'black', 'inflatable', 'ramp']
# ['person', 'covered', 'in', 'soapy', 'water', 'is', 'getting', 'cleaned', 'off']
# ['boy', 'in', 'blue', 'shorts', 'slides', 'down', 'slide', 'into', 'pool']
# ['boy', 'in', 'blue', 'swimming', 'trunks', 'slides', 'down', 'yellow', 'slide', 'into', 'wading', 'pool', 'with', 'inflatable', 'toys', 'floating', 'in', 'the', 'water']
# ['boy', 'rides', 'down', 'slide', 'into', 'small', 'backyard', 'pool']
# ['boy', 'sliding', 'down', 'slide', 'into', 'pool', 'with', 'colorful', 'tubes']
# ['child', 'is', 'falling', 'off', 'slide', 'onto', 'colored', 'balloons', 'floating', 'on', 'pool', 'of', 'water']
# ['man', 'in', 'wetsuit', 'is', 'throwing', 'baby', 'wearing', 'wetsuit', 'up', 'into', 'the', 'air']
# ['man', 'in', 'wetsuit', 'is', 'throwing', 'toddler', 'up', 'in', 'the', 'air', 'and', 'is', 'ready', 'to', 'catch', 'him']
# ['man', 'in', 'water', 'throwing', 'little', 'boy', 'up', 'in', 'the', 'air', 'and', 'waiting', 'for', 'him', 'to', 'come', 'down', 'so', 'he', 'can', 'catch', 'him']
# ['the', 'man', 'is', 'in', 'the', 'pool', 'and', 'throwing', 'small', 'boy', 'into', 'the', 'air']
# ['while', 'water', 'droplets', 'fly', 'man', 'throws', 'little', 'boy', 'up', 'in', 'the', 'air']
# ['little', 'boy', 'sticks', 'his', 'tongue', 'out', 'for', 'the', 'camera', 'another', 'boy', 'looks', 'on']
# ['two', 'boys', 'make', 'faces']
# ['two', 'young', 'boys', 'are', 'looking', 'at', 'the', 'camera', 'one', 'smiling', 'the', 'other', 'sticking', 'his', 'tongue', 'out']
# ['two', 'young', 'boys', 'look', 'up', 'at', 'the', 'camera', 'as', 'one', 'sticks', 'out', 'his', 'tongue']
# ['two', 'young', 'boys', 'making', 'silly', 'faces']
# ['blonde', 'horse', 'and', 'blonde', 'girl', 'in', 'black', 'sweatshirt', 'are', 'staring', 'at', 'fire', 'in', 'barrel']
# ['girl', 'and', 'her', 'horse', 'stand', 'by', 'fire']
# ['girl', 'holding', 'horse', 'lead', 'behind', 'fire']
# ['man', 'and', 'girl', 'and', 'two', 'horses', 'are', 'near', 'contained', 'fire']
# ['two', 'people', 'and', 'two', 'horses', 'watching', 'fire']
# ['bulldog', 'sheep', 'dog', 'and', 'boxer', 'standing', 'in', 'yard']
# ['large', 'brown', 'dog', 'is', 'pushing', 'small', 'boston', 'terrier', 'with', 'his', 'face', 'while', 'anouther', 'dog', 'watches']
# ['large', 'skinny', 'dog', 'stands', 'near', 'two', 'smaller', 'dogs', 'int', 'the', 'dirt']
# ['there', 'are', 'three', 'dogs', 'starring', 'at', 'ball', 'in', 'the', 'middle', 'of', 'them']
# ['three', 'dogs', 'of', 'various', 'sizes']
# ['lady', 'and', 'man', 'with', 'no', 'shirt', 'sit', 'on', 'dock']
# ['man', 'and', 'woman', 'are', 'sitting', 'on', 'dock', 'together']
# ['man', 'and', 'woman', 'sitting', 'on', 'dock']
# ['man', 'and', 'woman', 'sitting', 'on', 'deck', 'next', 'to', 'lake']
# ['shirtless', 'man', 'and', 'woman', 'sitting', 'on', 'dock']
# ['closeup', 'of', 'white', 'dog', 'that', 'is', 'laying', 'its', 'head', 'on', 'its', 'paws']
# ['large', 'white', 'dog', 'lying', 'on', 'the', 'floor']
# ['white', 'dog', 'has', 'its', 'head', 'on', 'the', 'ground']
# ['white', 'dog', 'is', 'resting', 'its', 'head', 'on', 'tiled', 'floor', 'with', 'its', 'eyes', 'open']
# ['white', 'dog', 'rests', 'its', 'head', 'on', 'the', 'patio', 'bricks']
# ['woman', 'in', 'yellow', 'shirt', 'and', 'green', 'shorts', 'is', 'climbing', 'an', 'artificial', 'red', 'wall', 'whilst', 'wearing', 'safety', 'harness']
# ['woman', 'in', 'blue', 'shorts', 'and', 'white', 'shirt', 'is', 'indoor', 'rock', 'climbing']
# ['the', 'girl', 'is', 'climbing', 'rock', 'wall']
# ['the', 'girl', 'is', 'in', 'harness', 'climbing', 'rocks']
# ['woman', 'climbing', 'an', 'artificial', 'rock', 'wall']
# ['boy', 'is', 'jumping', 'on', 'an', 'inflatable', 'ring', 'and', 'girl', 'is', 'watching', 'him']
# ['boy', 'jumping', 'on', 'water', 'jumphouse']
# ['teenage', 'boy', 'is', 'jumping', 'on', 'an', 'inflatable', 'slide']
# ['young', 'boy', 'jumping', 'and', 'young', 'girl', 'seating', 'in', 'an', 'inflatable', 'pool']
# ['two', 'young', 'kids', 'are', 'playing', 'in', 'the', 'water', 'on', 'an', 'inflated', 'toy']
# ['family', 'playing', 'on', 'tractor', 'on', 'beautiful', 'day']
# ['children', 'ride', 'tractor', 'in', 'field']
# ['several', 'children', 'playing', 'on', 'polaris', 'vehicle', 'outdoors']
# ['the', 'children', 'played', 'on', 'the', 'four', 'wheeler', 'in', 'the', 'field']
# ['the', 'four', 'kids', 'are', 'riding', 'on', 'an', 'atv', 'in', 'field']
# ['woman', 'in', 'red', 'costume', 'to', 'the', 'left', 'of', 'man', 'and', 'woman', 'standing', 'together']
# ['woman', 'wearing', 'red', 'costume', 'looks', 'at', 'two', 'other', 'people', 'standing', 'on', 'street']
# ['young', 'woman', 'in', 'red', 'sequined', 'costume', 'and', 'feather', 'stands', 'on', 'the', 'sidewalk']
# ['the', 'girl', 'in', 'the', 'salmon', 'colored', 'bikini', 'is', 'standing', 'next', 'to', 'two', 'young', 'people', 'one', 'is', 'wearing', 'black', 'outfit', 'and', 'the', 'other', 'is', 'drinking', 'pop']
# ['two', 'young', 'people', 'are', 'approached', 'by', 'flamboyant', 'young', 'woman', 'dressed', 'in', 'red', 'bikini', 'and', 'red', 'feathered', 'headress']
# ['skiiers', 'walking', 'up', 'the', 'hill', 'through', 'forest']
# ['two', 'men', 'are', 'skiing', 'in', 'the', 'snow', 'in', 'wooded', 'area']
# ['two', 'people', 'wearing', 'yellow', 'jackets', 'cross', 'country', 'skiing']
# ['two', 'skiers', 'are', 'making', 'their', 'way', 'through', 'woodland']
# ['two', 'skiers', 'are', 'sliding', 'down', 'trail', 'in', 'the', 'woods']
# ['lone', 'skier', 'is', 'making', 'their', 'way', 'up', 'mountain']
# ['skiiers', 'at', 'the', 'top', 'of', 'snow', 'covered', 'hill']
# ['two', 'hikers', 'climbing', 'snowy', 'hill']
# ['two', 'people', 'are', 'on', 'snow', 'covered', 'mountain']
# ['two', 'people', 'climbing', 'up', 'snowy', 'mountain']
# ['brown', 'dog', 'running', 'down', 'paved', 'pathway']
# ['brown', 'dog', 'running', 'next', 'to', 'grass']
# ['dog', 'is', 'running', 'down', 'road']
# ['light', 'brown', 'dog', 'runs', 'down', 'path', 'happily']
# ['energetic', 'brown', 'dog', 'running']
# ['mother', 'and', 'children', 'is', 'fishing', 'on', 'boardwalk', 'at', 'night']
# ['woman', 'and', 'three', 'children', 'stand', 'on', 'deck', 'with', 'fishing', 'pole']
# ['woman', 'stands', 'with', 'children', 'on', 'boardwalk', 'at', 'night', 'overlooking', 'the', 'sea']
# ['some', 'people', 'on', 'pier', 'at', 'night', 'with', 'one', 'girl', 'fishing', 'off', 'it']
# ['woman', 'with', 'three', 'children', 'fishing', 'over', 'boardwalk', 'in', 'the', 'evening']
# ['woman', 'dressed', 'in', 'blue', 'jacket', 'and', 'blue', 'jeans', 'rides', 'brown', 'horse', 'near', 'frozen', 'lake', 'and', 'snow', 'covered', 'mountain']
# ['woman', 'in', 'blue', 'jacket', 'rides', 'brown', 'pony', 'near', 'water']
# ['woman', 'rides', 'horse', 'near', 'frozen', 'lake', 'in', 'the', 'wintertime']
# ['young', 'blond', 'woman', 'sitting', 'atop', 'brown', 'draft', 'horse', 'in', 'the', 'snowy', 'mountains']
# ['woman', 'blue', 'jacket', 'sits', 'on', 'daft', 'horse', 'near', 'frozen', 'lake']
# ['two', 'draft', 'horses', 'pull', 'cart', 'through', 'the', 'snow']
# ['two', 'golden', 'brown', 'horses', 'pull', 'sleigh', 'driven', 'by', 'woman', 'in', 'blue', 'coat']
# ['two', 'horses', 'are', 'pulling', 'woman', 'in', 'cart']
# ['two', 'horses', 'pull', 'carriage', 'driven', 'by', 'woman', 'over', 'snow', 'covered', 'ground']
# ['two', 'horses', 'pulling', 'sled', 'steered', 'by', 'smiling', 'blond', 'woman']
# ['person', 'climbing', 'down', 'sheer', 'rock', 'cliff', 'using', 'rope']
# ['person', 'climbs', 'tall', 'flat', 'mountain', 'while', 'holding', 'onto', 'safety', 'rope']
# ['person', 'is', 'climbing', 'rock', 'while', 'holding', 'onto', 'white', 'rope']
# ['person', 'rappels', 'down', 'steep', 'incline']
# ['person', 'wearing', 'red', 'vest', 'climbs', 'up', 'steep', 'rock']
# ['people', 'stand', 'inside', 'rock', 'dome']
# ['shaft', 'of', 'light', 'in', 'cave', 'shows', 'three', 'spelunkers']
# ['spelunkers', 'pose', 'inside', 'rock', 'cavern', 'while', 'bathed', 'in', 'sunlight', 'from', 'the', 'surface']
# ['three', 'people', 'sit', 'in', 'cave']
# ['three', 'rock', 'climbers', 'are', 'posing', 'on', 'big', 'rocks']
# ['group', 'of', 'backpackers', 'lay', 'on', 'the', 'dry', 'ground']
# ['group', 'of', 'hikers', 'are', 'resting', 'on', 'the', 'ground', 'in', 'front', 'of', 'some', 'mountains']
# ['people', 'camp', 'with', 'the', 'mountains', 'in', 'the', 'background']
# ['several', 'hikers', 'rest', 'with', 'their', 'gear', 'in', 'front', 'of', 'mountain']
# ['the', 'group', 'of', 'hikers', 'is', 'resting', 'in', 'front', 'of', 'mountain']
# ['woman', 'in', 'blue', 'dress', 'stands', 'with', 'chalk', 'portrait', 'of', 'two', 'children', 'playing', 'by', 'stream']
# ['woman', 'standing', 'in', 'front', 'of', 'chalk', 'drawing']
# ['woman', 'stands', 'next', 'to', 'chalk', 'drawing', 'in', 'front', 'of', 'barn', 'like', 'structure']
# ['woman', 'stands', 'outside', 'near', 'an', 'elaborate', 'chalk', 'illustration']
# ['woman', 'wearing', 'blue', 'dress', 'is', 'drawing', 'picture', 'of', 'boy', 'and', 'girl', 'on', 'the', 'sidewalk', 'with', 'sidewalk', 'chalk']
# ['brown', 'dog', 'plays', 'in', 'deep', 'pile', 'of', 'snow']
# ['dog', 'looking', 'at', 'the', 'camera', 'in', 'snow']
# ['dog', 'runs', 'through', 'the', 'snow']
# ['tan', 'dog', 'stand', 'in', 'the', 'snow', 'and', 'looks', 'up']
# ['the', 'brown', 'dog', 'is', 'out', 'in', 'the', 'snow']
# ['boy', 'jumping', 'in', 'fountain']
# ['boy', 'plays', 'in', 'the', 'fountains']
# ['child', 'plays', 'in', 'fountain']
# ['little', 'boy', 'playing', 'in', 'the', 'water']
# ['young', 'boy', 'is', 'jumping', 'through', 'water', 'being', 'sprayed', 'up', 'from', 'the', 'ground']
# ['corgi', 'runs', 'out', 'of', 'tunnel']
# ['dog', 'runs', 'out', 'of', 'tunnel', 'on', 'course']
# ['dog', 'running', 'out', 'of', 'tunnel', 'on', 'obstacle', 'course']
# ['the', 'dog', 'is', 'running', 'out', 'of', 'the', 'tunnel', 'on', 'dog', 'obedience', 'course']
# ['the', 'small', 'brown', 'and', 'white', 'dog', 'is', 'running', 'out', 'of', 'small', 'tunnel']
# ['blond', 'dog', 'and', 'black', 'and', 'white', 'dog', 'run', 'in', 'dirt', 'field']
# ['dog', 'chases', 'another', 'dog']
# ['yellow', 'dog', 'and', 'black', 'and', 'white', 'dog', 'are', 'running', 'in', 'the', 'dirt']
# ['two', 'dogs', 'are', 'running', 'in', 'field']
# ['two', 'dogs', 'running', 'around']
# ['little', 'girl', 'in', 'blue', 'swimsuit', 'is', 'walking', 'along', 'wooden', 'fence', 'next', 'to', 'sandy', 'beach']
# ['little', 'girl', 'with', 'arms', 'outstretched', 'is', 'posing', 'at', 'the', 'beach']
# ['young', 'girl', 'walks', 'on', 'railing', 'in', 'front', 'of', 'the', 'beach']
# ['little', 'girl', 'in', 'blue', 'swimsuit', 'standing', 'on', 'handrail', 'near', 'beach']
# ['the', 'little', 'girl', 'in', 'the', 'blue', 'bathing', 'suit', 'is', 'posing', 'at', 'the', 'beach']
# ['black', 'and', 'white', 'dog', 'drinking', 'water', 'from', 'water', 'spray']
# ['black', 'and', 'white', 'dog', 'is', 'being', 'soaked', 'with', 'jet', 'of', 'water', 'in', 'blue', 'paddling', 'pool']
# ['dog', 'sticking', 'its', 'face', 'into', 'the', 'shower', 'from', 'garden', 'hose']
# ['small', 'white', 'dog', 'gets', 'sprayed', 'by', 'water']
# ['white', 'and', 'black', 'dog', 'is', 'jumping', 'into', 'pool']
# ['boy', 'smiles', 'underwater']
# ['red', 'headed', 'boy', 'swimming', 'underwater']
# ['small', 'boy', 'swimming', 'underwater']
# ['smiling', 'boy', 'swims', 'underwater', 'in', 'pool']
# ['the', 'boys', 'smiles', 'underwater', 'at', 'the', 'pool']
# ['boy', 'with', 'toy', 'gun']
# ['little', 'boy', 'in', 'orange', 'shorts', 'playing', 'with', 'toy']
# ['young', 'boy', 'with', 'his', 'foot', 'outstretched', 'aims', 'toy', 'at', 'the', 'camera', 'in', 'front', 'of', 'fireplace']
# ['young', 'child', 'plays', 'with', 'his', 'new', 'light', 'up', 'toy']
# ['boy', 'with', 'toy', 'gun', 'pointed', 'at', 'the', 'camera']
# ['boy', 'in', 'yellow', 'shorts', 'is', 'standing', 'on', 'top', 'of', 'cliff']
# ['boy', 'wearing', 'blue', 'and', 'yellow', 'walking', 'on', 'cliff', 'edge']
# ['little', 'boy', 'standing', 'high', 'in', 'the', 'air', 'on', 'rock']
# ['young', 'child', 'is', 'standing', 'alone', 'on', 'some', 'jagged', 'rocks']
# ['child', 'stands', 'near', 'edge', 'of', 'cliff']
# ['person', 'on', 'snowmobile', 'in', 'mid', 'jump']
# ['snowmobiler', 'flies', 'through', 'the', 'air']
# ['snowmobile', 'rider', 'flies', 'through', 'the', 'air', 'on', 'his', 'or', 'her', 'machine', 'in', 'front', 'of', 'tall', 'pine', 'trees']
# ['rider', 'jumps', 'snowmobile', 'high', 'in', 'rural', 'area']
# ['the', 'man', 'is', 'up', 'in', 'the', 'air']
# ['people', 'are', 'riding', 'around', 'on', 'snowmobiles']
# ['people', 'pose', 'with', 'helmets', 'and', 'goggles', 'on', 'while', 'riding', 'snowmobiles']
# ['several', 'people', 'are', 'taking', 'break', 'while', 'on', 'snowmobiling', 'ride']
# ['three', 'people', 'and', 'two', 'snowmobiles']
# ['two', 'helmeted', 'men', 'sit', 'on', 'yellow', 'snowmobiles', 'while', 'another', 'man', 'stands', 'behind', 'watching']
# ['three', 'people', 'drive', 'atvs']
# ['three', 'people', 'on', 'atvs', 'in', 'brown', 'field', 'turn', 'their', 'heads', 'to', 'look', 'at', 'the', 'camera']
# ['three', 'people', 'on', 'atv', 'outside']
# ['three', 'people', 'on', 'four', 'wheel', 'atv', 'in', 'field']
# ['three', 'people', 'ride', 'their', 'four', 'wheelers', 'through', 'the', 'field']
# ['four', 'wheeler', 'jumping', 'in', 'an', 'empty', 'field']
# ['man', 'on', 'four', 'wheeler', 'is', 'flying', 'through', 'the', 'air']
# ['person', 'is', 'riding', 'an', 'orange', 'atv', 'in', 'large', 'empty', 'field']
# ['man', 'jumping', 'with', 'all', 'terrain', 'vehicle']
# ['man', 'on', 'an', 'atv', 'catching', 'air']
# ['man', 'jumps', 'gin', 'the', 'air', 'while', 'riding', 'an', 'atv']
# ['man', 'on', 'four', 'wheeler', 'jumps', 'near', 'small', 'building']
# ['an', 'atv', 'is', 'airborne', 'over', 'field', 'in', 'front', 'of', 'white', 'structure']
# ['person', 'dressed', 'in', 'tan', 'jacket', 'jumps', 'quad', 'over', 'harvested', 'cornfield', 'in', 'front', 'of', 'small', 'out', 'building']
# ['man', 'on', 'four', 'wheeler', 'in', 'the', 'air']
# ['boy', 'in', 'striped', 'shirt', 'is', 'jumping', 'in', 'front', 'of', 'water', 'fountain']
# ['boy', 'is', 'jumping', 'off', 'the', 'side', 'of', 'running', 'stone', 'water', 'fountain', 'in', 'front', 'of', 'building']
# ['happy', 'boy', 'is', 'jumping', 'in', 'front', 'od', 'city', 'fountain']
# ['little', 'boy', 'is', 'jumping', 'in', 'front', 'of', 'fountain']
# ['little', 'boy', 'is', 'playfully', 'jumping', 'off', 'the', 'side', 'of', 'fountain']
# ['boy', 'carrying', 'soccer', 'ball']
# ['boy', 'walks', 'with', 'ball', 'tucked', 'under', 'his', 'arm']
# ['boy', 'walks', 'with', 'soccer', 'ball', 'near', 'fence']
# ['boy', 'wearing', 'white', 'shirt', 'walks', 'on', 'the', 'grass', 'and', 'carries', 'soccer', 'ball']
# ['small', 'boy', 'carries', 'soccer', 'ball', 'on', 'field']
# ['child', 'painting', 'picture']
# ['an', 'artist', 'paints', 'clouds', 'onto', 'canvas']
# ['young', 'girl', 'painting', 'picture']
# ['young', 'girl', 'with', 'braids', 'is', 'painting', 'with', 'water', 'colors', 'on', 'white', 'paper', 'on', 'the', 'wall']
# ['the', 'child', 'paints', 'on', 'large', 'paper', 'with', 'water', 'colors']
# ['cyclist', 'is', 'riding', 'bicycle', 'on', 'curved', 'road', 'up', 'hill']
# ['man', 'in', 'aerodynamic', 'gear', 'riding', 'bicycle', 'down', 'road', 'around', 'sharp', 'curve']
# ['man', 'on', 'mountain', 'bike', 'is', 'pedaling', 'up', 'hill']
# ['man', 'bicycle', 'up', 'road', 'while', 'cows', 'graze', 'on', 'hill', 'nearby']
# ['the', 'biker', 'is', 'riding', 'around', 'curve', 'in', 'the', 'road']
# ['black', 'dog', 'jumping', 'to', 'catch', 'rope', 'toy']
# ['black', 'dog', 'playing', 'fetch', 'with', 'ball', 'of', 'rope']
# ['black', 'dog', 'pounces', 'to', 'get', 'rope', 'toy']
# ['black', 'dog', 'running', 'after', 'his', 'rope', 'toy']
# ['large', 'black', 'dog', 'is', 'playing', 'in', 'grassy', 'yard']
# ['little', 'girl', 'is', 'holding', 'cine', 'camera', 'in', 'front', 'of', 'her', 'face']
# ['young', 'girl', 'is', 'looking', 'through', 'an', 'old', 'fashioned', 'video', 'camera']
# ['young', 'girl', 'steadies', 'her', 'aim', 'with', 'camera']
# ['girl', 'with', 'rosy', 'cheeks', 'and', 'lips', 'holding', 'black', 'toy', 'gun']
# ['there', 'is', 'kid', 'with', 'gun']
# ['black', 'and', 'white', 'border', 'collie', 'catches', 'frisbee', 'in', 'front', 'of', 'an', 'audience']
# ['brown', 'and', 'white', 'dog', 'catches', 'frisbee', 'in', 'it', 'mouth', 'in', 'front', 'of', 'group', 'of', 'people']
# ['brown', 'and', 'white', 'dug', 'jumping', 'up', 'to', 'catch', 'frisbee', 'while', 'an', 'audience', 'watches']
# ['dog', 'jumps', 'to', 'catch', 'frisbee', 'while', 'many', 'people', 'watch']
# ['an', 'agile', 'dog', 'catches', 'frisbee', 'while', 'crowd', 'of', 'onlookers', 'watches', 'closely']
# ['baby', 'is', 'sitting', 'on', 'and', 'playing', 'with', 'smooth', 'rocks']
# ['baby', 'is', 'stacking', 'rocks', 'on', 'the', 'beach']
# ['small', 'boy', 'is', 'playing', 'with', 'rocks']
# ['toddler', 'sitting', 'on', 'pile', 'of', 'rocks', 'holding', 'rock', 'at', 'beach']
# ['toddler', 'sits', 'on', 'pile', 'of', 'rocks']
# ['kid', 'rock', 'climbing', 'against', 'the', 'backdrop', 'of', 'green', 'valley']
# ['woman', 'in', 'striped', 'shirt', 'climbs', 'up', 'mountain']
# ['young', 'man', 'climbs', 'rocky', 'hill']
# ['the', 'person', 'has', 'striped', 'shirt', 'on', 'and', 'is', 'holding', 'on', 'to', 'rope', 'on', 'mountain']
# ['the', 'person', 'in', 'the', 'striped', 'shirt', 'is', 'mountain', 'climbing']
# ['man', 'climbing', 'rock', 'wall']
# ['man', 'climbing', 'the', 'side', 'of', 'cliff']
# ['man', 'is', 'rock', 'climbing']
# ['man', 'with', 'red', 'shoes', 'white', 'shirt', 'and', 'grey', 'pants', 'climbing']
# ['the', 'young', 'man', 'with', 'the', 'white', 'shirt', 'and', 'jeans', 'is', 'rappeling', 'up', 'the', 'rock', 'wall']
# ['climber', 'wearing', 'blue', 'helmet', 'and', 'headlamp', 'is', 'attached', 'to', 'rope', 'on', 'the', 'rock', 'face']
# ['man', 'climbs', 'rocky', 'wall']
# ['rock', 'climber', 'climbs', 'large', 'rock']
# ['woman', 'in', 'purple', 'snakeskin', 'pants', 'climbs', 'rock']
# ['person', 'with', 'blue', 'helmet', 'and', 'purple', 'pants', 'is', 'rock', 'climbing']
# ['child', 'playing', 'with', 'fountain', 'at', 'the', 'beach']
# ['child', 'plays', 'with', 'fountain']
# ['girl', 'looks', 'at', 'fountain', 'that', 'sprays', 'water']
# ['little', 'girl', 'playing', 'in', 'water', 'on', 'frog', 'sculpture']
# ['the', 'little', 'girl', 'is', 'playing', 'with', 'toy', 'in', 'public', 'fountain']
# ['black', 'dog', 'is', 'jumping', 'over', 'log', 'along', 'beach']
# ['black', 'dog', 'runs', 'along', 'the', 'beach', 'and', 'jumps', 'over', 'wood', 'barrior']
# ['dog', 'is', 'running', 'on', 'the', 'beach']
# ['dog', 'jumping', 'over', 'small', 'wall', 'at', 'beach', 'near', 'the', 'water']
# ['an', 'animal', 'is', 'running', 'on', 'the', 'beach']
# ['black', 'and', 'white', 'bird', 'eating', 'seeds', 'out', 'of', 'someone', 'hand']
# ['black', 'and', 'white', 'bird', 'standing', 'on', 'hand']
# ['small', 'bird', 'sits', 'in', 'person', 'hand', 'and', 'eats', 'seeds']
# ['black', 'and', 'white', 'bird', 'standing', 'on', 'hand', 'of', 'someone', 'holding', 'sunflower', 'seeds']
# ['the', 'small', 'bird', 'is', 'clinging', 'to', 'finger', 'of', 'the', 'hand', 'holding', 'the', 'seeds']
# ['brown', 'dog', 'is', 'running', 'in', 'the', 'sand']
# ['brown', 'dog', 'playing', 'in', 'the', 'sand']
# ['brown', 'dog', 'plays', 'at', 'the', 'beach']
# ['dog', 'is', 'standing', 'in', 'the', 'sand']
# ['dog', 'running', 'fast', 'in', 'the', 'sand']
# ['little', 'boy', 'stands', 'in', 'the', 'surf']
# ['small', 'child', 'wades', 'through', 'the', 'water', 'while', 'being', 'guided', 'by', 'another', 'person']
# ['young', 'boy', 'laughs', 'while', 'splashing', 'in', 'the', 'ocean']
# ['young', 'boy', 'wearing', 'colorful', 'bathing', 'suit', 'splashing', 'in', 'the', 'ocean']
# ['young', 'child', 'splashing', 'in', 'water']
# ['little', 'tan', 'dog', 'with', 'large', 'ears', 'running', 'through', 'the', 'grass']
# ['playful', 'dog', 'is', 'running', 'through', 'the', 'grass']
# ['small', 'dogs', 'ears', 'stick', 'up', 'as', 'it', 'runs', 'in', 'the', 'grass']
# ['the', 'small', 'dog', 'is', 'running', 'across', 'the', 'lawn']
# ['this', 'is', 'small', 'beige', 'dog', 'running', 'through', 'grassy', 'field']
# ['black', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'field']
# ['black', 'brown', 'and', 'white', 'dog', 'running', 'through', 'field']
# ['brown', 'black', 'and', 'white', 'dog', 'is', 'running', 'through', 'large', 'field', 'with', 'its', 'mouth', 'open']
# ['dog', 'running', 'in', 'field']
# ['dog', 'with', 'its', 'mouth', 'open', 'running', 'through', 'field', 'torwards', 'the', 'camera']
# ['girl', 'in', 'pink', 'swimsuit', 'in', 'pool']
# ['girl', 'swimming', 'in', 'pool']
# ['little', 'girl', 'in', 'pink', 'bathing', 'suit', 'swimming', 'in', 'pool']
# ['little', 'girl', 'swimming', 'in', 'pool']
# ['smiling', 'little', 'girl', 'swimming', 'in', 'outdoor', 'pool']
# ['child', 'is', 'standing', 'on', 'her', 'head']
# ['little', 'girl', 'standing', 'on', 'her', 'head']
# ['small', 'child', 'doing', 'handstand', 'on', 'bed']
# ['young', 'girl', 'does', 'handstand', 'on', 'bed', 'with', 'blue', 'sheets']
# ['the', 'girl', 'is', 'upside', 'down', 'on', 'bed']
# ['guy', 'stands', 'in', 'the', 'sand', 'with', 'snowboard', 'behind', 'him']
# ['man', 'holds', 'surfboard', 'on', 'the', 'beach']
# ['man', 'holds', 'his', 'snowboard', 'in', 'the', 'sand']
# ['man', 'with', 'his', 'surfboard', 'stands', 'in', 'the', 'sand']
# ['man', 'is', 'standing', 'on', 'white', 'sand', 'and', 'holding', 'snowboard']
# ['people', 'on', 'atvs', 'and', 'dirt', 'bikes', 'are', 'traveling', 'along', 'worn', 'path', 'in', 'field', 'surrounded', 'by', 'trees']
# ['three', 'people', 'are', 'riding', 'around', 'on', 'atv', 'and', 'motorcycles']
# ['three', 'people', 'on', 'motorbikes', 'follow', 'trail', 'through', 'dry', 'grass']
# ['three', 'people', 'on', 'two', 'dirt', 'bikes', 'and', 'one', 'four', 'wheeler', 'are', 'riding', 'through', 'brown', 'grass']
# ['three', 'people', 'ride', 'off', 'road', 'bikes', 'through', 'field', 'surrounded', 'by', 'trees']
# ['baby', 'in', 'white', 'garment', 'holds', 'flag', 'with', 'crescent', 'moon', 'and', 'star']
# ['baby', 'is', 'holding', 'small', 'black', 'flag', 'with', 'moon', 'and', 'star', 'on', 'it']
# ['baby', 'wearing', 'white', 'gown', 'waves', 'muslim', 'flag']
# ['little', 'toddler', 'dressed', 'in', 'white', 'is', 'smiling', 'while', 'lady', 'helps', 'him', 'wave', 'flag']
# ['baby', 'in', 'white', 'outfit', 'holding', 'black', 'and', 'white', 'flag']
# ['half', 'naked', 'man', 'is', 'sleeping', 'on', 'his', 'chair', 'outdoors']
# ['an', 'older', 'man', 'sits', 'back', 'and', 'relaxes', 'on', 'patio', 'outside', 'an', 'adobe', 'building', 'where', 'many', 'bicycles', 'are', 'propped']
# ['shirtless', 'man', 'in', 'white', 'cap', 'relaxes', 'in', 'deck', 'chair', 'close', 'to', 'three', 'parked', 'bicycles']
# ['man', 'relaxing', 'in', 'folding', 'chair', 'on', 'the', 'street']
# ['topless', 'old', 'man', 'wearing', 'slippers', 'navy', 'blue', 'pants', 'and', 'white', 'hat', 'while', 'reclining', 'in', 'chair', 'outside']
# ['brown', 'and', 'white', 'and', 'black', 'and', 'white', 'dog', 'hauling', 'in', 'floating', 'toy', 'from', 'the', 'ocean']
# ['both', 'dogs', 'retrieve', 'the', 'play', 'toy', 'from', 'the', 'water']
# ['two', 'dogs', 'in', 'the', 'ocean', 'playing', 'with', 'toy']
# ['two', 'dogs', 'run', 'through', 'the', 'water', 'with', 'rope', 'in', 'their', 'mouths']
# ['two', 'dogs', 'tug', 'at', 'chew', 'toy', 'in', 'the', 'surf']
# ['there', 'are', 'three', 'young', 'people', 'one', 'dark', 'haired', 'holding', 'bottled', 'drink', 'one', 'with', 'head', 'tilted', 'back', 'and', 'finger', 'in', 'her', 'mouth', 'and', 'one', 'with', 'spiked', 'hair']
# ['the', 'young', 'people', 'party', 'in', 'the', 'streets']
# ['three', 'girls', 'make', 'faces', 'as', 'one', 'takes', 'drink', 'while', 'they', 'stand', 'in', 'busy', 'street']
# ['three', 'women', 'on', 'the', 'street', 'drinking', 'and', 'posing']
# ['three', 'young', 'women', 'pose', 'for', 'the', 'camera', 'at', 'parade']
# ['brown', 'dog', 'is', 'running', 'through', 'neck', 'deep', 'water', 'carrying', 'tennis', 'ball']
# ['brown', 'dog', 'splashes', 'in', 'the', 'water', 'while', 'carrying', 'ball', 'in', 'its', 'mouth']
# ['brown', 'dog', 'swims', 'through', 'water', 'outdoors', 'with', 'tennis', 'ball', 'in', 'its', 'mouth']
# ...
# ['man', 'wearing', 'lots', 'of', 'plaid', 'riding', 'bike', 'through', 'the', 'streets']
# ['person', 'wearing', 'blue', 'and', 'white', 'coat', 'rides', 'bicycle', 'down', 'the', 'street']
# ['person', 'riding', 'their', 'bicycle', 'on', 'the', 'street', 'with', 'backpack', 'on']
# ['girl', 'in', 'yellow', 'top', 'is', 'paddling', 'wooden', 'boat', 'past', 'wooden', 'jetty']
# ['girl', 'paddles', 'canoe']
# ['girl', 'rows', 'boat', 'from', 'dock']
# ['girl', 'pushing', 'boat', 'with', 'pole', 'in', 'the', 'water']
# ['the', 'girl', 'is', 'paddling', 'rusty', 'canoe', 'in', 'the', 'water']
# ['black', 'dog', 'is', 'jumping', 'over', 'white', 'fence', 'whilst', 'taking', 'part', 'in', 'dog', 'show']
# ['dog', 'leaps', 'over', 'the', 'hurdle']
# ['small', 'dog', 'leaps', 'over', 'striped', 'hurdle']
# ['white', 'black', 'and', 'brown', 'dog', 'jumping', 'over', 'hurdle']
# ['the', 'dog', 'is', 'leaping', 'over', 'the', 'bar']
# ['golden', 'haired', 'dog', 'with', 'wet', 'hair', 'is', 'licking', 'its', 'nose', 'while', 'moving', 'through', 'shallow', 'water']
# ['golden', 'retriever', 'licks', 'his', 'nose', 'as', 'he', 'dries', 'off', 'from', 'the', 'water']
# ['long', 'haired', 'dog', 'walks', 'out', 'of', 'the', 'water', 'and', 'licks', 'his', 'nose']
# ['wet', 'brown', 'dog', 'is', 'leaving', 'the', 'water']
# ['the', 'brown', 'dog', 'is', 'running', 'in', 'the', 'water', 'licking', 'his', 'nose']
# ['dark', 'colored', 'man', 'is', 'holding', 'protest', 'banner', 'in', 'busy', 'city', 'street', 'with', 'people', 'staring', 'from', 'behind']
# ['man', 'in', 'blue', 'and', 'yellow', 'jacket', 'holding', 'religious', 'sign', 'stands', 'in', 'street', 'with', 'people', 'behind', 'him', 'on', 'the', 'sidewalk']
# ['man', 'is', 'holding', 'religious', 'poster']
# ['man', 'wearing', 'hat', 'holding', 'sign', 'with', 'writing', 'on', 'it']
# ['man', 'standing', 'on', 'the', 'street', 'holding', 'sign']
# ['brown', 'dog', 'howls']
# ['brown', 'dog', 'in', 'the', 'grass', 'field', 'is', 'looking', 'up', 'at', 'the', 'sky']
# ['brown', 'dog', 'is', 'crouching', 'and', 'looking', 'up', 'in', 'field', 'of', 'grass']
# ['large', 'brown', 'dog', 'is', 'crouching', 'in', 'grassy', 'field']
# ['brown', 'dog', 'crouching', 'in', 'grass', 'looking', 'up']
# ['collie', 'and', 'springer', 'spaniel', 'playing', 'outside']
# ['the', 'large', 'brown', 'and', 'white', 'dog', 'is', 'jumping', 'towards', 'the', 'small', 'brown', 'and', 'white', 'dog']
# ['two', 'brown', 'and', 'white', 'dogs', 'fighting', 'on', 'grassy', 'area', 'in', 'front', 'of', 'tree']
# ['two', 'brown', 'and', 'white', 'dogs', 'in', 'the', 'grass', 'near', 'stone', 'structure']
# ['two', 'tan', 'and', 'white', 'dogs', 'look', 'at', 'each', 'other', 'in', 'an', 'outdoor', 'setting']
# ['brown', 'and', 'white', 'dog', 'is', 'walking', 'through', 'some', 'wasteland']
# ['collie', 'runs', 'across', 'yard', 'in', 'the', 'springtime']
# ['collie', 'surrounded', 'by', 'leafless', 'bushes']
# ['dog', 'that', 'looks', 'like', 'lassie', 'walking', 'in', 'the', 'fields']
# ['the', 'dog', 'is', 'in', 'front', 'of', 'some', 'bushes']
# ['people', 'hiking', 'through', 'an', 'icy', 'hilly', 'landscape']
# ['three', 'men', 'hike', 'in', 'the', 'snow']
# ['three', 'people', 'backpacking', 'across', 'large', 'snowy', 'and', 'rocky', 'field']
# ['three', 'people', 'walking', 'across', 'an', 'icy', 'hill']
# ['three', 'people', 'walk', 'on', 'snow', 'covered', 'wasteland']
# ['dog', 'jumps', 'man', 'leg', 'to', 'take', 'frisbee', 'from', 'his', 'hand']
# ['dog', 'jumps', 'for', 'the', 'frisbee', 'the', 'girl', 'is', 'holding']
# ['person', 'in', 'black', 'coat', 'playing', 'frisbee', 'with', 'dog', 'near', 'wooded', 'area']
# ['woman', 'and', 'dog', 'play', 'with', 'disk', 'in', 'field']
# ['the', 'dog', 'owner', 'attempts', 'to', 'retrieve', 'the', 'frisbee', 'from', 'her', 'pet']
# ['person', 'does', 'trick', 'on', 'skateboard']
# ['skateboarder', 'is', 'doing', 'trick', 'in', 'midair']
# ['he', 'is', 'doing', 'tricks', 'on', 'the', 'skateboard']
# ['there', 'is', 'the', 'bottom', 'of', 'skateboard', 'off', 'the', 'ground', 'with', 'someone', 'in', 'blue', 'jeans', 'holding', 'it']
# ['this', 'skateboarder', 'wearing', 'jeans', 'and', 'tennis', 'shoes', 'grabs', 'the', 'board', 'while', 'in', 'the', 'air']
# ['couple', 'looking', 'at', 'red', 'sculpture']
# ['man', 'and', 'woman', 'looking', 'at', 'red', 'sculpture']
# ['man', 'and', 'woman', 'look', 'back', 'at', 'the', 'camera', 'while', 'standing', 'in', 'front', 'of', 'red', 'art', 'structure']
# ['man', 'and', 'woman', 'stand', 'in', 'front', 'of', 'large', 'red', 'modern', 'statue']
# ['man', 'and', 'woman', 'stand', 'near', 'large', 'red', 'sculpture', 'outdoors']
# ['photo', 'of', 'smiling', 'young', 'woman', 'in', 'front', 'of', 'tables', 'on', 'the', 'street']
# ['woman', 'in', 'jacket', 'is', 'posing', 'for', 'camera', 'smiling', 'in', 'mostly', 'empty', 'restaurant']
# ['young', 'girl', 'standing', 'outside', 'restaurant', 'at', 'night']
# ['young', 'woman', 'wearing', 'turtle', 'neck', 'and', 'black', 'jacket', 'is', 'smiling', 'for', 'picture']
# ['the', 'little', 'girl', 'is', 'wearing', 'black', 'sweater', 'and', 'standing', 'in', 'front', 'of', 'restaurant']
# ['girl', 'in', 'gray', 'shirt', 'and', 'brown', 'hair', 'relaxes', 'on', 'the', 'lawn', 'as', 'dogs', 'bound', 'around', 'her']
# ['woman', 'sitting', 'next', 'to', 'her', 'purse', 'watching', 'dogs', 'at', 'the', 'park']
# ['young', 'woman', 'sits', 'crosslegged', 'beside', 'her', 'purse', 'on', 'the', 'grass', 'among', 'crowd', 'of', 'dogs']
# ['there', 'are', 'several', 'dogs', 'in', 'the', 'field', 'where', 'the', 'girl', 'with', 'the', 'ponytail', 'is', 'sitting', 'down']
# ['woman', 'sitting', 'in', 'the', 'grass', 'with', 'many', 'dogs', 'around', 'her']
# ['dog', 'approachs', 'small', 'creature', 'in', 'barren', 'snowy', 'field']
# ['black', 'dog', 'in', 'snowy', 'field']
# ['black', 'dog', 'running', 'through', 'grassy', 'area']
# ['two', 'dogs', 'are', 'running', 'towards', 'some', 'long', 'grass', 'in', 'the', 'scrubland']
# ['two', 'dogs', 'run', 'in', 'field', 'of', 'brown', 'grass']
# ['couple', 'walking', 'down', 'the', 'street', 'carrying', 'bags']
# ['man', 'and', 'woman', 'are', 'carrying', 'bags', 'down', 'an', 'empty', 'street']
# ['man', 'and', 'woman', 'walking', 'down', 'street', 'carrying', 'luggage']
# ['two', 'people', 'carrying', 'various', 'items', 'walking', 'down', 'city', 'street']
# ['two', 'people', 'carry', 'their', 'bags', 'down', 'an', 'unpaved', 'road']
# ['couple', 'are', 'sitting', 'on', 'rock', 'in', 'front', 'of', 'street']
# ['man', 'and', 'woman', 'sit', 'on', 'rock', 'beside', 'street']
# ['two', 'people', 'sit', 'on', 'large', 'rock', 'near', 'city', 'street']
# ['two', 'people', 'sitting', 'on', 'rock', 'in', 'city', 'park']
# ['two', 'people', 'talk', 'while', 'sitting', 'on', 'big', 'rock']
# ['brown', 'dog', 'chasing', 'frisbee', 'barbeque', 'in', 'the', 'background']
# ['brown', 'dog', 'is', 'trying', 'to', 'catch', 'flying', 'disk', 'but', 'missed', 'it']
# ['dog', 'is', 'twisting', 'in', 'the', 'air', 'as', 'it', 'tries', 'to', 'catch', 'frisbee']
# ['brown', 'dog', 'plays', 'with', 'frisbee']
# ['the', 'brown', 'dog', 'dives', 'backwards', 'to', 'catch', 'the', 'football']
# ['man', 'prepares', 'to', 'enter', 'the', 'red', 'building']
# ['man', 'walking', 'around', 'the', 'corner', 'of', 'red', 'building']
# ['man', 'walks', 'past', 'red', 'building', 'with', 'fake', 'rocket', 'attached', 'to', 'it']
# ['man', 'walks', 'under', 'building', 'with', 'large', 'rocket', 'shaped', 'sculpture']
# ['person', 'walking', 'by', 'red', 'building', 'with', 'jet', 'on', 'top', 'of', 'it']
# ['brown', 'doberman', 'is', 'outside', 'with', 'stick', 'in', 'its', 'mouth']
# ['brown', 'dog', 'shows', 'his', 'teeth']
# ['dog', 'bites', 'stick']
# ['dog', 'is', 'biting', 'twig']
# ['dog', 'with', 'sharp', 'teeth', 'is', 'chewing', 'on', 'stick', 'outside']
# ['couple', 'posing', 'in', 'front', 'of', 'picture', 'wall']
# ['an', 'adult', 'couple', 'pose', 'by', 'cardboard', 'cut', 'out', 'for', 'movie']
# ['an', 'asian', 'couple', 'are', 'standing', 'by', 'fantasy', 'poster']
# ['an', 'asian', 'couple', 'stands', 'near', 'wax', 'figure']
# ['one', 'person', 'in', 'brown', 'suit', 'with', 'his', 'arm', 'around', 'another', 'in', 'hat', 'by', 'wall']
# ['bus', 'filled', 'with', 'passengers', 'in', 'chicago', 'at', 'night']
# ['bus', 'full', 'of', 'people', 'waiting', 'at', 'stop']
# ['people', 'are', 'sitting', 'on', 'bus']
# ['people', 'in', 'bus', 'which', 'is', 'heading', 'to', 'peterson']
# ['there', 'are', 'people', 'sitting', 'on', 'bus', 'that', 'is', 'labeled', 'peterson']
# ['woman', 'is', 'sitting', 'on', 'sidewalk', 'with', 'cellphone', 'at', 'her', 'ear']
# ['woman', 'rests', 'on', 'the', 'curb', 'of', 'city', 'street', 'while', 'talking', 'on', 'her', 'cellphone']
# ['woman', 'sits', 'on', 'the', 'curb', 'while', 'talking', 'on', 'her', 'cellphone']
# ['woman', 'sits', 'on', 'the', 'edge', 'of', 'sidewalk', 'with', 'garbage', 'bin', 'beside', 'her']
# ['woman', 'sits', 'on', 'the', 'curb', 'talking', 'on', 'cellphone']
# ['caravan', 'of', 'snowmobile', 'travel', 'through', 'the', 'snow']
# ['pair', 'of', 'people', 'in', 'heavy', 'winter', 'jackets', 'rides', 'through', 'the', 'snow', 'on', 'snowmobile']
# ['people', 'riding', 'something', 'in', 'the', 'snow']
# ['person', 'on', 'polaris', 'ski', 'mobile', 'in', 'the', 'snow']
# ['the', 'man', 'wearing', 'blue', 'helmet', 'is', 'riding', 'polaris']
# ['dark', 'colored', 'man', 'is', 'laying', 'on', 'newspapers', 'by', 'metal', 'railing', 'with', 'his', 'shoes', 'off']
# ['homeless', 'man', 'is', 'lying', 'on', 'the', 'ground', 'with', 'his', 'stuff', 'strewn', 'around']
# ['homeless', 'man', 'is', 'sleeping', 'outside', 'at', 'the', 'top', 'of', 'staircase']
# ['an', 'man', 'is', 'sleeping', 'on', 'top', 'of', 'his', 'clothes', 'on', 'concrete', 'stairs']
# ['man', 'sleeping', 'on', 'the', 'street']
# ['boy', 'in', 'red', 'and', 'girl', 'pink', 'are', 'walking', 'through', 'low', 'cut', 'field']
# ['the', 'little', 'boy', 'and', 'little', 'girl', 'are', 'walking', 'side', 'by', 'side']
# ['two', 'small', 'children', 'walk', 'away', 'in', 'field']
# ['two', 'small', 'children', 'walking', 'in', 'field']
# ['two', 'young', 'children', 'are', 'walking', 'across', 'an', 'open', 'field']
# ['two', 'men', 'sitting', 'on', 'the', 'bank', 'of', 'lake', 'with', 'an', 'ice', 'chest']
# ['two', 'people', 'having', 'picnic', 'by', 'lake']
# ['two', 'people', 'having', 'picnic', 'by', 'the', 'shore']
# ['two', 'people', 'sitting', 'on', 'grass', 'in', 'front', 'of', 'lake', 'looking', 'at', 'the', 'sky']
# ['two', 'people', 'with', 'hats', 'looking', 'at', 'lake', 'while', 'sitting', 'on', 'yellow', 'grassed', 'hill']
# ['people', 'possibly', 'fishermen', 'with', 'their', 'boats', 'in', 'shadow', 'on', 'shore', 'at', 'an', 'orangesunset']
# ['man', 'in', 'an', 'orange', 'vest', 'is', 'standing', 'next', 'to', 'yellow', 'canoe']
# ['people', 'tend', 'canoes', 'at', 'the', 'edge', 'of', 'body', 'of', 'water', 'during', 'dimly', 'lit', 'time', 'of', 'day']
# ['the', 'men', 'are', 'getting', 'their', 'kayaks', 'secured', 'on', 'the', 'beach', 'for', 'the', 'night']
# ['two', 'men', 'standing', 'on', 'the', 'shore', 'beside', 'their', 'kayaks', 'at', 'dusk']
# ['cluster', 'of', 'four', 'brown', 'dogs', 'play', 'in', 'field', 'of', 'brown', 'grass']
# ['four', 'dogs', 'are', 'together', 'in', 'the', 'field', 'of', 'dry', 'grass']
# ['four', 'dogs', 'in', 'grassy', 'area']
# ['four', 'medium', 'sized', 'dogs', 'wrestle', 'with', 'each', 'other', 'on', 'grass', 'field']
# ['four', 'small', 'dogs', 'play', 'outside']
# ['girl', 'is', 'hiding', 'behind', 'painted', 'wooden', 'structure', 'inside', 'building']
# ['little', 'girl', 'with', 'red', 'dress', 'facing', 'panel', 'with', 'her', 'back', 'to', 'the', 'camera']
# ['young', 'blonde', 'girl', 'wearing', 'red', 'dress', 'kneeling', 'on', 'red', 'carpet']
# ['young', 'girl', 'faces', 'white', 'and', 'black', 'wall', 'in', 'red', 'carpeted', 'room']
# ['girl', 'kneeling', 'on', 'red', 'carpet']
# ['brown', 'dogs', 'and', 'woman', 'in', 'yard']
# ['brown', 'dog', 'persues', 'frisbee', 'across', 'the', 'grass', 'as', 'the', 'thrower', 'watches']
# ['woman', 'in', 'blue', 'jacket', 'watches', 'as', 'her', 'two', 'brown', 'dogs', 'play', 'with', 'red', 'ball', 'in', 'grassy', 'yard']
# ['woman', 'throws', 'frisbee', 'for', 'her', 'two', 'brown', 'dogs', 'to', 'chase']
# ['woman', 'watches', 'brown', 'dog', 'run', 'away', 'from', 'house', 'across', 'the', 'grass']
# ['clown', 'shares', 'cut', 'out', 'pictures', 'of', 'children']
# ['dirty', 'looking', 'clown', 'holding', 'up', 'two', 'paper', 'cut', 'outs', 'of', 'children', 'with', 'blond', 'hair']
# ['man', 'wearing', 'balloon', 'hat', 'and', 'grassy', 'shirt', 'holds', 'up', 'two', 'large', 'paper', 'dolls']
# ['man', 'wearing', 'balloon', 'hat', 'holds', 'up', 'colored', 'cut', 'out', 'drawings', 'of', 'two', 'men']
# ['the', 'man', 'wears', 'balloons', 'on', 'his', 'head', 'and', 'holds', 'paper', 'people']
# ['group', 'of', 'people', 'walk', 'through', 'shopping', 'mall']
# ['many', 'people', 'walk', 'through', 'the', 'store']
# ['people', 'browse', 'in', 'store']
# ['people', 'strolling', 'through', 'an', 'indoor', 'market']
# ['the', 'shoppers', 'are', 'walking', 'in', 'store']
# ['black', 'man', 'with', 'red', 'mask', 'is', 'carrying', 'box']
# ['man', 'in', 'domino', 'mask', 'carries', 'an', 'amplifier', 'up', 'hill']
# ['man', 'with', 'mask', 'carrying', 'black', 'speaker']
# ['masked', 'man', 'in', 'bright', 'clothing', 'carrying', 'large', 'box']
# ['black', 'man', 'lifting', 'black', 'box', 'is', 'watched', 'by', 'black', 'dog']
# ['the', 'black', 'dog', 'runs', 'with', 'ball', 'with', 'two', 'smaller', 'dogs', 'behind', 'it']
# ['three', 'dogs', 'playing', 'in', 'field', 'one', 'with', 'ball', 'in', 'its', 'mouth']
# ['three', 'dogs', 'race', 'towards', 'the', 'viewer', 'over', 'lawn']
# ['three', 'dogs', 'running', 'in', 'grass', 'one', 'carrying', 'tennis', 'ball', 'in', 'mouth']
# ['two', 'small', 'dogs', 'follow', 'larger', 'dog', 'with', 'tennis', 'ball']
# ['couple', 'watches', 'boat', 'against', 'skyline']
# ['man', 'and', 'woman', 'sit', 'on', 'bench', 'watching', 'boat', 'go', 'by']
# ['the', 'sun', 'is', 'setting', 'while', 'man', 'and', 'woman', 'watch', 'boat', 'go', 'by']
# ['two', 'people', 'sit', 'on', 'bench', 'and', 'watch', 'boat', 'on', 'the', 'water']
# ['two', 'people', 'watching', 'boat', 'sail', 'past']
# ['female', 'jogger', 'wearing', 'red']
# ['girl', 'with', 'headphones', 'is', 'running', 'next', 'to', 'some', 'street', 'signs']
# ['woman', 'in', 'red', 'outfit', 'is', 'jogging', 'next', 'to', 'several', 'street', 'signs']
# ['woman', 'jogging', 'across', 'an', 'intersection']
# ['the', 'lady', 'in', 'red', 'shorts', 'jogs', 'near', 'stop', 'sign', 'while', 'listening', 'to', 'music']
# ['bearded', 'man', 'wearing', 'denim', 'jacket', 'and', 'hat', 'sits', 'on', 'park', 'bench']
# ['bearded', 'man', 'wearing', 'denim', 'jacket', 'sits', 'on', 'bench']
# ['man', 'with', 'bushy', 'beard', 'and', 'baseball', 'cap', 'sits', 'on', 'park', 'bench']
# ['an', 'old', 'man', 'with', 'long', 'beard', 'and', 'jean', 'jacket', 'sits', 'on', 'park', 'bench']
# ['an', 'old', 'man', 'with', 'long', 'white', 'beard', 'glasses', 'and', 'hat', 'is', 'sitting', 'on', 'park', 'bench']
# ['bird', 'lands', 'on', 'mans', 'glove']
# ['man', 'holds', 'bird']
# ['man', 'holds', 'falcon', 'on', 'his', 'arm']
# ['gloved', 'man', 'holding', 'bird', 'of', 'prey']
# ['the', 'man', 'is', 'wearing', 'gloves', 'and', 'holding', 'hawk', 'in', 'his', 'hands']
# ['brown', 'dog', 'has', 'white', 'toy', 'in', 'its', 'mouth']
# ['dog', 'holding', 'white', 'stuffed', 'animal']
# ['tan', 'dog', 'hangong', 'on', 'to', 'white', 'plushie', 'toy']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
dictionary["1000268201_693b08cb0e"]
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %% [markdown]
# ### save our preprocessing part

# %%
with open("descriptions_new1.txt","w") as f:
    f.write(str(dictionary)) ## dictionary with your clean data is saved into your file
    
    ####                         CLEAN DATA IS SAVED INTO THE FILE ##########################

# %% [markdown]
# ### VOCABULARY

# %%
descriptions=None
with open("descriptions_new1.txt","r") as f:
    descriptions=f.read()

# %%
print(type(descriptions))
# Out:
# <class 'str'>

# %% [markdown]
# ### coverting this str to dict type we will require json

# %%
json_accpetable_string=descriptions.replace("'","\"")
descriptions=json.loads(json_accpetable_string) ## for converting it to dictionary

# %%
print(type(descriptions))
# Out:
# <class 'dict'>

# %%
## vocab

vocab=set() ## stores the unique word

for key in descriptions.keys():
    [vocab.update(sentence.split()) for sentence in descriptions[key]] 
    
    
    ### keeping only those words in the dictionary which are unique so that we can create a effective vocab size

# %%
len(vocab) 

### total unique words present in the captions list
# Out:
# 8424

# %% [markdown]
# ### we will remove very infrequent words so that our vocab size reduces

# %% [markdown]
# ## counting the total words

# %%
## keeping only those words in the vocab which are very very important(occurs more than a threshold value)

total_words=[]

for key in descriptions.keys():
    [total_words.append(i) for des in descriptions[key] for i in des.split()]

    
    ### here "des" is the list of the captios where as "i" is the word in that particular caption and we append it in total_words
print(len(total_words))
# Out:
# 373837

# %% [markdown]
# ### filter the words from the vocab which have frequency greater than some threshold frequency

# %% [markdown]
# ### only 8424 words are unique

# %%
counter=collections.Counter(total_words)### it will give you the frequency of each word
freq_cnt=dict(counter)

# %% [markdown]
# ### sorting the dict according to the freq_cnt

# %%
sorted_freq_cnt=sorted(freq_cnt.items(),reverse=True,key=lambda x:x[1])


### now filteration
threshold=10
sorted_freq_cnt=[x for x in sorted_freq_cnt if x[1]>threshold ]  ## only adding words which have frequency count greater than 10

total_words=[x[0] for x in sorted_freq_cnt]  ## final vocab

# %%
print(len(total_words))
# Out:
# 1845

# %% [markdown]
# ### preparing train and test data

# %%
train_file_data=readText("./flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr_8k.trainImages.txt")
test_file_data=readText("./flickr8k/Flickr_Data/Flickr_Data/Flickr_TextData/Flickr_8k.testImages.txt")

# %%
train=[row.split('.')[0] for row in train_file_data.split("\n")[:-1]]
test=[row.split('.')[0] for row in test_file_data.split("\n")[:-1]]

# %%
print(train[:10])
# Out:
# ['2513260012_03d33305cf', '2903617548_d3e38d7f88', '3338291921_fe7ae0c8f8', '488416045_1c6d903fe0', '2644326817_8f45080b87', '218342358_1755a9cce1', '2501968935_02f2cd8079', '2699342860_5288e203ea', '2638369467_8fc251595b', '2926786902_815a99a154']

# %% [markdown]
# ## we have to add start and end token to our training data to stop generating the sentence or when generating multiple sentences

# %%
train_descriptions={} ## subset of descriptions dictionary

for img_id in train:
    train_descriptions[img_id]=[]
    for cap in descriptions[img_id]:
        cap_to_app="startseq " + cap + " endseq"
        train_descriptions[img_id].append(cap_to_app)

# %%
train_descriptions["1000268201_693b08cb0e"]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq']

# %% [markdown]
# ### Creating our model Through transfer learning

# %%
model=ResNet50(weights="imagenet",input_shape=(224,224,3))
model.summary()
# Out:
# WARNING:tensorflow:From c:\users\mohit\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\users\mohit\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model_new=Model(model.input,model.layers[-2].output)

# %%
def preprocess_img(img):
    img= image.load_img(img,target_size=(224,224))
    img= image.img_to_array(img)    ### when you feed an image to resnet you can not feed single image you have to feed by batch
                                   #### which creates a 4d tensor   
    img= np.expand_dims(img,axis=0)  ## it creates 4d tensor
    
    ### normalisation
    img=preprocess_input(img)  ## preprocessing done by keras by subtracting mean (see documentation)
    
    return img

# %% [markdown]
# ### this the Resnet50 way of representing the picture using some normalisation

# %%
img=preprocess_img(img_path+"1000268201_693b08cb0e.jpg")
plt.imshow(img[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def encode_img(img):
    img=preprocess_img(img)
    feature_vector=model_new.predict(img)
    feature_vector=feature_vector.reshape((-1,))
    #print(feature_vector.shape)
    return feature_vector

# %%
x=img_path+"1000268201_693b08cb0e.jpg"
print(x)
encode_img(x)
# Out:
# flickr8k/Flickr_Data/Flickr_Data/Images/1000268201_693b08cb0e.jpg
# WARNING:tensorflow:From c:\users\mohit\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# array([0.04154464, 0.17075905, 0.29276785, ..., 0.05094026, 0.3131964 ,
#        0.8600726 ], dtype=float32)

# %% [markdown]
# ### now we have to do encoding for each of the image and we have to save it

# %%
encoding_train={}
start=time()
for ix,img_id in enumerate(train):
    IMG_path=img_path+img_id+".jpg"
    encoding_train[img_id]=encode_img(IMG_path)
    
    
    if ix%100==0:
        print(" encoding in progress %d "%ix)
        
        
end_t=time()
#print("%d"%end_t-start)
# Out:
#  encoding in progress 0
#  encoding in progress 100
#  encoding in progress 200
#  encoding in progress 300
#  encoding in progress 400
#  encoding in progress 500
#  encoding in progress 600
#  encoding in progress 700
#  encoding in progress 800
#  encoding in progress 900
#  encoding in progress 1000
#  encoding in progress 1100
#  encoding in progress 1200
#  encoding in progress 1300
#  encoding in progress 1400
#  encoding in progress 1500
#  encoding in progress 1600
#  encoding in progress 1700
#  encoding in progress 1800
#  encoding in progress 1900
#  encoding in progress 2000
#  encoding in progress 2100
#  encoding in progress 2200
#  encoding in progress 2300
#  encoding in progress 2400
#  encoding in progress 2500
#  encoding in progress 2600
#  encoding in progress 2700
#  encoding in progress 2800
#  encoding in progress 2900
#  encoding in progress 3000
#  encoding in progress 3100
#  encoding in progress 3200
#  encoding in progress 3300
#  encoding in progress 3400
#  encoding in progress 3500
#  encoding in progress 3600
#  encoding in progress 3700
#  encoding in progress 3800
#  encoding in progress 3900
#  encoding in progress 4000
#  encoding in progress 4100
#  encoding in progress 4200
#  encoding in progress 4300
#  encoding in progress 4400
#  encoding in progress 4500
#  encoding in progress 4600
#  encoding in progress 4700
#  encoding in progress 4800
#  encoding in progress 4900
#  encoding in progress 5000
#  encoding in progress 5100
#  encoding in progress 5200
#  encoding in progress 5300
#  encoding in progress 5400
#  encoding in progress 5500
#  encoding in progress 5600
#  encoding in progress 5700
#  encoding in progress 5800
#  encoding in progress 5900

# %% [markdown]
# #### storing it into a disk
# #### pickle allows you to switch between Ram and file

# %%
with open("encoded_train_features.pkl","wb") as f:
    pickle.dump(encoding_train,f)

# %%
encoding_test={}
start=time()
for ix,img_id in enumerate(test):
    IMG_path=img_path+img_id+".jpg"
    encoding_test[img_id]=encode_img(IMG_path)
    
    
    if ix%100==0:
        print(" encoding in progress %d "%ix)
        
        
end_t=time()
#print("%d"%end_t-start)
# Out:
#  encoding in progress 0
#  encoding in progress 100
#  encoding in progress 200
#  encoding in progress 300
#  encoding in progress 400
#  encoding in progress 500
#  encoding in progress 600
#  encoding in progress 700
#  encoding in progress 800
#  encoding in progress 900

# %%
with open("encoded_test_features2.pkl","wb") as f:
    pickle.dump(encoding_train,f)

# %% [markdown]
# ### data preprocessing for the captions

# %% [markdown]
# ### mapping words with numbers to feed into our model

# %%
word_to_idx={}
idx_to_word={}

for i,word in enumerate(total_words):
    word_to_idx[word]=i+1   ### mapping word with number
    idx_to_word[i+1]=word   ### then number with the word

# %% [markdown]
# ### we have to add two special words

# %%
idx_to_word[1846]="startseq"
word_to_idx["startseq"]=1846

idx_to_word[1847]="endseq"
word_to_idx["endseq"]=1847

# %% [markdown]
# ## from captions we have to find some max caption which can determine the batch_size

# %%
maxlen=0

for key in descriptions.keys():
    for cap in descriptions[key]:
        maxlen=max(maxlen,len(cap.split()))
        
print(maxlen)
# Out:
# 33

# %% [markdown]
# ## data loader

# %%
word_to_idx["in"]
# Out:
# 1

# %%
idx_to_word[100]
# Out:
# 'dirt'

# %%
def data_generator(train_descriptions,encoding_train,word_to_idx,maxlen,batch_size):
    X1,X2,y=[],[],[]
    
    n=0
    while True:
        for key,dec_list in train_descriptions.items():
            n+=1
            photo=encode_img(key+".jpg")
            for desc in dec_list:
                seq=[word_to_idx[word] for word in desc.split() if word in word_to_idx] ## converting list of numbers of the words which are present
                
                ### [13 46 64 83 19 ]
                ### len is 5
                ### so everytime we take one number more from the list
                ### 13
                ### 13 46
                ### 13 46 64 
                ### 13 46 83 19
                for i in range(1,len(seq)):
                    xi=seq[0:i]
                    yi=seq[i]
                   
                    ## xero is the padded word
                    
                    xi=pad_sequences([xi],maxlen=maxlen,value=0,padding='post')[0]
                    yi=to_categorical([yi],num_classes=vocab_size)[0]  ### one hot vector for neural network
                    
                    X1.append(photo)
                    X2.append(xi)
                    y.append(yi)
                    
                if n==batch_size:
                    yield [[np.array(X1),np.array(X2)],np.array(y)]
                    
                    
                X1,X2,y=[]
                n=0

# %%
f=open("./glove6b50dtxt/glove.6B.50d.txt",encoding='utf8')

# %%
embedding_index={}

for line in f:
    values=line.split()
    #print(values)
    #break
    word=values[0]
    word_embedding=np.array(values[1:],dtype='float')
    embedding_index[word]= word_embedding

# %%
vocab_size=1848

# %%
def get_Embedding_matrix():
    emd_dim=50
    vocab_size=1848
    matrix=np.zeros((vocab_size,emd_dim))
    
    
    for word,idx in word_to_idx.items():
        embedding_vector=embedding_index.get(word)  ##here you get the vector from the embedding_index
        
        if embedding_vector is not None:
            matrix[idx]=embedding_vector
            ### whatever be the idx of the word ,paste the embedding vector at that index
    return matrix

# %%
f.close()

# %%
embedding_index['kite']
# Out:
# array([-0.53284 , -0.014537, -0.18404 ,  0.54987 , -0.61098 ,  0.39327 ,
#        -0.49495 , -0.51952 ,  0.78696 , -0.16896 ,  0.055488,  0.37429 ,
#        -0.31054 ,  1.1719  , -0.39846 ,  0.13731 ,  0.6917  ,  0.21903 ,
#        -1.7579  , -0.89281 , -0.46632 ,  0.34248 ,  0.22537 , -0.344   ,
#         0.63632 , -0.42802 , -0.32488 ,  0.070891, -0.11279 , -0.56122 ,
#         0.17763 ,  0.40187 , -0.27975 ,  1.3318  ,  0.11309 , -0.38383 ,
#         0.33596 ,  0.37865 , -0.55863 ,  0.43565 ,  0.17027 ,  0.44203 ,
#        -0.087287,  0.85622 ,  0.42661 , -0.057   ,  0.33    , -0.54549 ,
#        -0.63598 ,  0.15724 ])

# %%
mat=get_Embedding_matrix()

# %% [markdown]
# ### Model Architecture

# %%
input_img_f=Input(shape=(2048,)) ### the output of resnet is given to the input layer(with alreday extracted features)
inp_img1=Dropout(0.3)(input_img_f)
inp_img2=Dense(256,activation='relu')(inp_img1) ## output of previous to the input
## converting the 2048dim to 256 dim

# %% [markdown]
# ### captions

# %%
input_captions=Input(shape=(maxlen,))
inp_cap1=Embedding(input_dim=vocab_size,output_dim=50,mask_zero=True)(input_captions)
inp_cap2=Dropout(0.3)(inp_cap1)
inp_cap3=LSTM(256)(inp_cap2)
# Out:
# WARNING:tensorflow:From c:\users\mohit\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\keras\backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
decoder1=add([inp_img2,inp_cap3]) ### one is from the image and the other is from the captions we have generated 
### and then we concatenate them
decoder2=Dense(256,activation='relu')(decoder1)
outputs=Dense(vocab_size,activation='softmax')(decoder2)

################                             combined model #######################

model=Model([input_img_f,input_captions],outputs=outputs)
model.summary()
### nno parametre for add layer because we are just adding two layers
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 33)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 33, 50)       92400       input_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 33, 50)       0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          524544      dropout_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          314368      dropout_2[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 256)          0           dense_1[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          65792       add_17[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1848)         474936      dense_2[0][0]
# ==================================================================================================
# Total params: 1,472,040
# Trainable params: 1,472,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Important Thing -Embedding Layer(preintialise it )

# %%
model.layers[2].set_weights([mat])
model.layers[2].trainable=False

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam')
